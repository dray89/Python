# %%
#!pip install tabula-py

# %%
import tabula
import pandas as pd
import itertools

# %%
def get_column_list(dataframe_obj):
    '''
    Puts all the column names from a list of dataframes into a list
    
    input: list of dataframes
    output: lists of column names from all the dataframes
    '''
    columns = [list(dataframe_obj[i].columns) for i in range(len(dataframe_obj))]
    return columns

def get_series_list(dataframe_obj, columns_list):
    '''
    Turns all the columns in each of the dataframes to series and puts them all in a list
    
    input: list of dataframes and the column list from get_column_list
    output: list of panda series objects
    '''
    series_list = [dataframe_obj[i] for i in columns_list]
    series_list2 = [series_list[i].dropna() for i in range(len(series_list))]
    return series_list2

def append_columns(filtered_columns, to_series):
    '''
    Appends items to a pandas series object
    
    input: items to append and an object to append them to
    output: a series object with the appended items
    '''
    to_append = pd.Series(filtered_columns) 
    return to_series.append(to_append, ignore_index=True)

# %% [markdown]
# ##### Will output a list of dataframes (1 for each table in the pdf) BUT
# 1) The table has lost nearly all its organization
#
# 2) Some of the column names should actually be row values
#
# 3) NaN values litter the output

# %%
df = tabula.read_pdf(r"C:\Users\rayde\Downloads\2020-2021-Approved-Stock-List-20200926.pdf", pages = 'all', lattice = False, multiple_tables=True)
df
# Out:
# Got stderr: Oct 13, 2020 9:01:02 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:04 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:04 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:05 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:05 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:05 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:05 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:06 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:06 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:06 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:06 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:07 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:07 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:07 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:07 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:08 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:08 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:08 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:09 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:09 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:09 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:09 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:10 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:10 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:10 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font BVOMFL+ChaparralPro-Regular
# Oct 13, 2020 9:01:10 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font VSKGSX+ChaparralPro-Italic
# Oct 13, 2020 9:01:10 PM org.apache.pdfbox.pdmodel.font.PDFont loadUnicodeCmap
# WARNING: Invalid ToUnicode CMap in font VSKGSX+ChaparralPro-Italic
# [      Abercrombie & Fitch     ANF            New York Stock    Small Value  \
#  0                      Co     NaN            Exchange, Inc.            NaN
#  1     Acorn International     ATV            New York Stock  Not Available
#  2                     Inc     NaN            Exchange, Inc.            NaN
#  3          Amazon.com Inc    AMZN                    Nasdaq   Large Growth
#  4          American Eagle     AEO            New York Stock    Small Value
#  5           Out!tters Inc     NaN            Exchange, Inc.            NaN
#  6               Aptiv PLC    APTV            New York Stock     Mid Growth
#  7                     NaN     NaN            Exchange, Inc.            NaN
#  8       Avon Products Inc     AVP            New York Stock   Small Growth
#  9                     NaN     NaN            Exchange, Inc.            NaN
#  10        B2W - Companhia   BTOW3  B3 S.A. - Brasil, Bolsa,   Large Growth
#  11                Digital     NaN                    Balcão            NaN
#  12         Bajaj Auto Ltd  532977                   BSE LTD    Large Blend
#  13                    NaN     NaN                       NaN            NaN
#  14         Barnes & Noble    BNED            New York Stock    Small Blend
#  15          Education Inc     NaN            Exchange, Inc.            NaN
#  16         Bata India Ltd  500043                   BSE LTD     Mid Growth
#  17                    NaN     NaN                       NaN            NaN
#  18      Bed Bath & Beyond    BBBY                    Nasdaq    Small Value
#  19                    Inc     NaN                       NaN            NaN
#  20        Best Buy Co Inc     BBY            New York Stock      Mid Value
#  21                    NaN     NaN            Exchange, Inc.            NaN
#  22         BorgWarner Inc     BWA            New York Stock      Mid Value
#  23                    NaN     NaN            Exchange, Inc.            NaN
#  24              Bosch Ltd  500530                   BSE LTD    Large Value
#  25    Boyd Group Services     BYD    Toronto Stock Exchange     Mid Growth
#  26                    Inc     NaN                       NaN            NaN
#  27           Build-A-Bear     BBW            New York Stock    Small Value
#  28           Workshop Inc     NaN            Exchange, Inc.            NaN
#  29  Burlington Stores Inc    BURL            New York Stock     Mid Growth
#  30                    NaN     NaN            Exchange, Inc.            NaN
#  31           Canada Goose    GOOS    Toronto Stock Exchange     Mid Growth
#  32           Holdings Inc     NaN                       NaN            NaN
#  33             CarMax Inc     KMX            New York Stock     Mid Growth
#  34                    NaN     NaN            Exchange, Inc.            NaN
#  35           Carnival PLC     CCL     London Stock Exchange    Small Value
#  36     Cheesecake Factory    CAKE                    Nasdaq    Small Value
#  37                    Inc     NaN                       NaN            NaN
#  38       China Automotive    CAAS                    Nasdaq    Small Value
#  39            Systems Inc     NaN                       NaN            NaN
#
#                 Retail    Specialty retail
#  0                 NaN                 NaN
#  1               Media         Advertising
#  2                 NaN            agencies
#  3              Retail   Diversi!ed retail
#  4              Retail    Specialty retail
#  5                 NaN                 NaN
#  6   Auto & Auto Parts          Auto parts
#  7                 NaN                 NaN
#  8   Consumer Products           Cosmetics
#  9                 NaN                 NaN
#  10             Retail   Diversi!ed retail
#  11                NaN                 NaN
#  12            Leisure        Recreational
#  13                NaN  vehicles and boats
#  14             Retail    Specialty retail
#  15                NaN                 NaN
#  16  Consumer Products    Textiles apparel
#  17                NaN           and shoes
#  18             Retail    Specialty retail
#  19                NaN                 NaN
#  20             Retail    Specialty retail
#  21                NaN                 NaN
#  22  Auto & Auto Parts          Auto parts
#  23                NaN                 NaN
#  24  Auto & Auto Parts          Auto parts
#  25  Auto & Auto Parts       Auto services
#  26                NaN                 NaN
#  27             Retail    Specialty retail
#  28                NaN                 NaN
#  29             Retail    Specialty retail
#  30                NaN                 NaN
#  31  Consumer Products    Textiles apparel
#  32                NaN           and shoes
#  33             Retail    Specialty retail
#  34                NaN                 NaN
#  35            Leisure        Leisure time
#  36            Leisure         Restaurants
#  37                NaN                 NaN
#  38  Auto & Auto Parts          Auto parts
#  39                NaN                 NaN  ,
#         China Tourism Group  601888 Shanghai Stock Exchange  Large Growth  \
#  0       Duty Free Corp Ltd     NaN                     NaN           NaN
#  1   Chipotle Mexican Grill     CMG          New York Stock  Large Growth
#  2                      Inc     NaN          Exchange, Inc.           NaN
#  3             Comcast Corp   CMCSA                  Nasdaq   Large Value
#  4                      NaN     NaN                     NaN           NaN
#  5        Compass Group PLC     CPG   London Stock Exchange   Large Blend
#  6                      NaN     NaN                     NaN           NaN
#  7        Core-Mark Holding    CORE                  Nasdaq   Small Blend
#  8                   Co Inc     NaN                     NaN           NaN
#  9         Costco Wholesale    COST                  Nasdaq   Large Blend
#  10                    Corp     NaN                     NaN           NaN
#  11      Daily Journal Corp    DJCO                  Nasdaq  Small Growth
#  12     Dollar General Corp      DG          New York Stock   Large Blend
#  13                     NaN     NaN          Exchange, Inc.           NaN
#  14         Dollar Tree Inc    DLTR                  Nasdaq     Mid Blend
#  15           Dollarama Inc     DOL  Toronto Stock Exchange    Mid Growth
#  16      Domino’s Pizza Inc     DPZ          New York Stock    Mid Growth
#  17                     NaN     NaN          Exchange, Inc.           NaN
#  18         Foot Locker Inc      FL          New York Stock   Small Blend
#  19                     NaN     NaN          Exchange, Inc.           NaN
#  20           Ford Motor Co       F          New York Stock   Large Value
#  21                     NaN     NaN          Exchange, Inc.           NaN
#  22                 Gap Inc     GPS          New York Stock     Mid Value
#  23                     NaN     NaN          Exchange, Inc.           NaN
#  24       General Motors Co      GM          New York Stock   Large Blend
#  25                     NaN     NaN          Exchange, Inc.           NaN
#  26           H&R Block Inc     HRB          New York Stock   Small Value
#  27                     NaN     NaN          Exchange, Inc.           NaN
#  28     Harley-Davidson Inc     HOG          New York Stock   Small Value
#  29                     NaN     NaN          Exchange, Inc.           NaN
#  30              Hasbro Inc     HAS                  Nasdaq     Mid Blend
#  31       Hero MotoCorp Ltd  500182                 BSE LTD   Large Value
#  32                     NaN     NaN                     NaN           NaN
#  33      Hibbett Sports Inc    HIBB                  Nasdaq   Small Blend
#  34      Honda Motor Co Ltd     HMC          New York Stock   Large Value
#  35                     NaN     NaN          Exchange, Inc.           NaN
#  36       Hostelworld Group     HSW   London Stock Exchange   Small Value
#  37                     PLC     NaN                     NaN           NaN
#  38       Hyatt Hotels Corp       H          New York Stock     Mid Blend
#  39                     NaN     NaN          Exchange, Inc.           NaN
#
#                Leisure         Hotel/motel
#  0                 NaN                 NaN
#  1             Leisure         Restaurants
#  2                 NaN                 NaN
#  3               Media    Cable television
#  4                 NaN            services
#  5   Consumer Services         Vending and
#  6                 NaN   catering services
#  7              Retail   Diversi!ed retail
#  8                 NaN                 NaN
#  9              Retail   Diversi!ed retail
#  10                NaN                 NaN
#  11              Media          Publishing
#  12             Retail   Diversi!ed retail
#  13                NaN                 NaN
#  14             Retail   Diversi!ed retail
#  15             Retail   Diversi!ed retail
#  16            Leisure         Restaurants
#  17                NaN                 NaN
#  18             Retail    Specialty retail
#  19                NaN                 NaN
#  20  Auto & Auto Parts         Automobiles
#  21                NaN                 NaN
#  22             Retail    Specialty retail
#  23                NaN                 NaN
#  24  Auto & Auto Parts         Automobiles
#  25                NaN                 NaN
#  26  Consumer Services  Consumer services:
#  27                NaN       Miscellaneous
#  28            Leisure        Recreational
#  29                NaN  vehicles and boats
#  30  Consumer Products                Toys
#  31            Leisure        Recreational
#  32                NaN  vehicles and boats
#  33             Retail    Specialty retail
#  34  Auto & Auto Parts         Automobiles
#  35                NaN                 NaN
#  36            Leisure        Leisure time
#  37                NaN                 NaN
#  38            Leisure         Hotel/motel
#  39                NaN                 NaN  ,
#                   Imax Corp    IMAX            New York Stock   Small Growth  \
#  0                      NaN     NaN            Exchange, Inc.            NaN
#  1         InterContinental     IHG     London Stock Exchange      Mid Blend
#  2         Hotels Group PLC     NaN                       NaN            NaN
#  3       Jubilant Foodworks  533155                   BSE LTD     Mid Growth
#  4                      Ltd     NaN                       NaN            NaN
#  5           Lands’ End Inc      LE                    Nasdaq    Small Blend
#  6     Las Vegas Sands Corp     LVS            New York Stock    Large Value
#  7                      NaN     NaN            Exchange, Inc.            NaN
#  8       LCI Industries Inc    LCII            New York Stock   Small Growth
#  9                      NaN     NaN            Exchange, Inc.            NaN
#  10  Localiza Rent A Car SA   RENT3  B3 S.A. - Brasil, Bolsa,   Large Growth
#  11                     NaN     NaN                    Balcão            NaN
#  12     Lojas Americanas SA   LAME4  B3 S.A. - Brasil, Bolsa,   Large Growth
#  13                     NaN     NaN                    Balcão            NaN
#  14         Lojas Renner SA   LREN3  B3 S.A. - Brasil, Bolsa,   Large Growth
#  15                     NaN     NaN                    Balcão            NaN
#  16             Lookers PLC    LOOK     London Stock Exchange    Small Value
#  17     Lululemon Athletica    LULU                    Nasdaq   Large Growth
#  18                     Inc     NaN                       NaN            NaN
#  19                Lyft Inc    LYFT                    Nasdaq  Not Available
#  20                     NaN     NaN                       NaN            NaN
#  21              Macy’s Inc       M            New York Stock    Small Value
#  22                     NaN     NaN            Exchange, Inc.            NaN
#  23       Magazine Luiza SA   MGLU3  B3 S.A. - Brasil, Bolsa,   Large Growth
#  24                     NaN     NaN                    Balcão            NaN
#  25     Mahindra & Mahindra  500520                   BSE LTD    Large Blend
#  26                     Ltd     NaN                       NaN            NaN
#  27  Marriott International     MAR                    Nasdaq    Large Value
#  28                     Inc     NaN                       NaN            NaN
#  29     Maruti Suzuki India  532500                   BSE LTD    Large Blend
#  30                     Ltd     NaN                       NaN            NaN
#  31              Mattel Inc     MAT                    Nasdaq    Small Blend
#  32         McDonald’s Corp     MCD            New York Stock    Large Blend
#  33                     NaN     NaN            Exchange, Inc.            NaN
#  34      Midea Group Co Ltd  000333   Shenzhen Stock Exchange    Large Blend
#  35                     NaN     NaN                       NaN            NaN
#  36        Movado Group Inc     MOV            New York Stock    Small Value
#  37                     NaN     NaN            Exchange, Inc.            NaN
#  38            New Oriental     EDU            New York Stock  Not Available
#  39             Education &     NaN            Exchange, Inc.            NaN
#  40    Technology Group Inc     NaN                       NaN            NaN
#  41                Next PLC     NXT     London Stock Exchange      Mid Blend
#
#                  Media       Entertainment
#  0                 NaN                 NaN
#  1             Leisure         Hotel/motel
#  2                 NaN                 NaN
#  3             Leisure         Restaurants
#  4                 NaN                 NaN
#  5              Retail   Diversi!ed retail
#  6             Leisure         Casinos and
#  7                 NaN            gambling
#  8             Leisure        Recreational
#  9                 NaN  vehicles and boats
#  10  Consumer Services  Rental and leasing
#  11                NaN  services: Consumer
#  12             Retail   Diversi!ed retail
#  13                NaN                 NaN
#  14             Retail   Diversi!ed retail
#  15                NaN                 NaN
#  16             Retail    Specialty retail
#  17  Consumer Products    Textiles apparel
#  18                NaN           and shoes
#  19  Consumer Services  Consumer services:
#  20                NaN       Miscellaneous
#  21             Retail   Diversi!ed retail
#  22                NaN                 NaN
#  23             Retail   Diversi!ed retail
#  24                NaN                 NaN
#  25  Auto & Auto Parts         Automobiles
#  26                NaN                 NaN
#  27            Leisure         Hotel/motel
#  28                NaN                 NaN
#  29  Auto & Auto Parts         Automobiles
#  30                NaN                 NaN
#  31  Consumer Products                Toys
#  32            Leisure         Restaurants
#  33                NaN                 NaN
#  34  Consumer Products           Household
#  35                NaN          appliances
#  36  Consumer Products        Luxury items
#  37                NaN                 NaN
#  38  Consumer Services  Education services
#  39                NaN                 NaN
#  40                NaN                 NaN
#  41             Retail   Diversi!ed retail  ,
#                   Nike Inc     NKE          New York Stock   Large Growth  \
#  0                     NaN     NaN          Exchange, Inc.            NaN
#  1   Norwegian Cruise Line    NCLH          New York Stock      Mid Blend
#  2            Holdings Ltd     NaN          Exchange, Inc.            NaN
#  3       On "e Beach Group     OTB   London Stock Exchange   Small Growth
#  4                     PLC     NaN                     NaN            NaN
#  5             Papa John’s    PZZA                  Nasdaq   Small Growth
#  6       International Inc     NaN                     NaN            NaN
#  7             Pearson PLC    PSON   London Stock Exchange      Mid Value
#  8      Planet Fitness Inc    PLNT          New York Stock     Mid Growth
#  9                     NaN     NaN          Exchange, Inc.            NaN
#  10   Red Lion Hotels Corp     RLH          New York Stock    Small Blend
#  11                    NaN     NaN          Exchange, Inc.            NaN
#  12      Restaurant Brands     QSR  Toronto Stock Exchange    Large Blend
#  13      International Inc     NaN                     NaN            NaN
#  14             Revlon Inc     REV          New York Stock    Small Value
#  15                    NaN     NaN          Exchange, Inc.            NaN
#  16           Ritchie Bros     RBA          New York Stock     Mid Growth
#  17        Auctioneers Inc     NaN          Exchange, Inc.            NaN
#  18     Sirius XM Holdings    SIRI                  Nasdaq    Large Blend
#  19                    Inc     NaN                     NaN            NaN
#  20         Smith & Wesson    SWBI                  Nasdaq    Small Blend
#  21             Brands Inc     NaN                     NaN            NaN
#  22         Starbucks Corp    SBUX                  Nasdaq    Large Blend
#  23         Stitch Fix Inc    SFIX                  Nasdaq   Small Growth
#  24    Tailored Brands Inc    TLRD          New York Stock    Small Value
#  25                    NaN     NaN          Exchange, Inc.            NaN
#  26    TAL Education Group     TAL          New York Stock  Not Available
#  27                    NaN     NaN          Exchange, Inc.            NaN
#  28            Target Corp     TGT          New York Stock    Large Blend
#  29                    NaN     NaN          Exchange, Inc.            NaN
#  30        Tata Motors Ltd  500570                 BSE LTD    Large Value
#  31              Tesla Inc    TSLA                  Nasdaq   Large Growth
#  32    Texas Roadhouse Inc    TXRH                  Nasdaq   Small Growth
#  33     "e Container Store     TCS          New York Stock    Small Value
#  34              Group Inc     NaN          Exchange, Inc.            NaN
#  35        "e Estee Lauder      EL          New York Stock    Large Blend
#  36          Companies Inc     NaN          Exchange, Inc.            NaN
#  37      "e Walt Disney Co     DIS          New York Stock    Large Blend
#  38                    NaN     NaN          Exchange, Inc.            NaN
#  39          "e Wendy’s Co     WEN                  Nasdaq      Mid Blend
#  40            Ti#any & Co     TIF          New York Stock      Mid Blend
#  41                    NaN     NaN          Exchange, Inc.            NaN
#
#      Consumer Products    Textiles apparel
#  0                 NaN           and shoes
#  1             Leisure        Leisure time
#  2                 NaN                 NaN
#  3             Leisure        Leisure time
#  4                 NaN                 NaN
#  5             Leisure         Restaurants
#  6                 NaN                 NaN
#  7   Consumer Services  Education services
#  8             Leisure        Leisure time
#  9                 NaN                 NaN
#  10            Leisure         Hotel/motel
#  11                NaN                 NaN
#  12            Leisure         Restaurants
#  13                NaN                 NaN
#  14  Consumer Products           Cosmetics
#  15                NaN                 NaN
#  16  Consumer Services  Consumer services:
#  17                NaN       Miscellaneous
#  18              Media        Radio and TV
#  19                NaN        broadcasters
#  20            Leisure        Leisure time
#  21                NaN                 NaN
#  22            Leisure         Restaurants
#  23             Retail   Diversi!ed retail
#  24             Retail    Specialty retail
#  25                NaN                 NaN
#  26  Consumer Services  Education services
#  27                NaN                 NaN
#  28             Retail   Diversi!ed retail
#  29                NaN                 NaN
#  30  Auto & Auto Parts         Automobiles
#  31  Auto & Auto Parts         Automobiles
#  32            Leisure         Restaurants
#  33             Retail    Specialty retail
#  34                NaN                 NaN
#  35  Consumer Products           Cosmetics
#  36                NaN                 NaN
#  37              Media       Entertainment
#  38                NaN                 NaN
#  39            Leisure         Restaurants
#  40  Consumer Products        Luxury items
#  41                NaN                 NaN  ,
#      Colgate-Palmolive Co      CL            New York Stock    Large Value  \
#  0                    NaN     NaN            Exchange, Inc.            NaN
#  1   Companhia Brasileira   PCAR4  B3 S.A. - Brasil, Bolsa,      Mid Value
#  2        De Distribuicao     NaN                    Balcão            NaN
#  3            Corteva Inc    CTVA            New York Stock  Not Available
#  4                    NaN     NaN            Exchange, Inc.            NaN
#  5        CVS Health Corp     CVS            New York Stock    Large Value
#  6                    NaN     NaN            Exchange, Inc.            NaN
#  7      General Mills Inc     GIS            New York Stock    Large Value
#  8                    NaN     NaN            Exchange, Inc.            NaN
#  9     Godrej Agrovet Ltd  540743                   BSE LTD      Mid Blend
#  10                   NaN     NaN                       NaN            NaN
#  11       Godrej Consumer  532424                   BSE LTD    Large Blend
#  12          Products Ltd     NaN                       NaN            NaN
#  13    Hindustan Unilever  500696                   BSE LTD   Large Growth
#  14                   Ltd     NaN                       NaN            NaN
#  15               ITC Ltd  500875                   BSE LTD    Large Blend
#  16                   NaN     NaN                       NaN            NaN
#
#      Personal Care, Drug       Personal care
#  0      & Grocery Stores                 NaN
#  1   Personal Care, Drug    Drug and grocery
#  2      & Grocery Stores        store chains
#  3      Food, Beverage &               Foods
#  4               Tobacco                 NaN
#  5   Personal Care, Drug    Drug and grocery
#  6      & Grocery Stores        store chains
#  7      Food, Beverage &               Foods
#  8               Tobacco                 NaN
#  9      Food, Beverage &  Agriculture !shing
#  10              Tobacco        and ranching
#  11  Personal Care, Drug       Personal care
#  12     & Grocery Stores                 NaN
#  13  Personal Care, Drug       Personal care
#  14     & Grocery Stores                 NaN
#  15     Food, Beverage &             Tobacco
#  16              Tobacco                 NaN  ,
#             Nestle India Ltd 500790                   BSE LTD  Large Growth  \
#  0                       NaN    NaN                       NaN           NaN
#  1               PepsiCo Inc    PEP                    Nasdaq   Large Value
#  2                       NaN    NaN                       NaN           NaN
#  3       Procter & Gamble Co     PG            New York Stock   Large Value
#  4                       NaN    NaN            Exchange, Inc.           NaN
#  5          Raia Drogasil SA  RADL3  B3 S.A. - Brasil, Bolsa,  Large Growth
#  6                       NaN    NaN                    Balcão           NaN
#  7         Reckitt Benckiser    RB.     London Stock Exchange   Large Blend
#  8                 Group PLC    NaN                       NaN           NaN
#  9             Rite Aid Corp    RAD            New York Stock   Small Value
#  10                      NaN    NaN            Exchange, Inc.           NaN
#  11        Sainsbury (J) PLC   SBRY     London Stock Exchange     Mid Value
#  12                      NaN    NaN                       NaN           NaN
#  13          Sprouts Farmers    SFM                    Nasdaq   Small Blend
#  14               Market Inc    NaN                       NaN           NaN
#  15               Sysco Corp    SYY            New York Stock   Large Value
#  16                      NaN    NaN            Exchange, Inc.           NaN
#  17            "e Hershey Co    HSY            New York Stock   Large Blend
#  18                      NaN    NaN            Exchange, Inc.           NaN
#  19  Tootsie Roll Industries     TR            New York Stock   Small Blend
#  20                      Inc    NaN            Exchange, Inc.           NaN
#  21      Treehouse Foods Inc    THS            New York Stock   Small Value
#  22                      NaN    NaN            Exchange, Inc.           NaN
#  23          Tyson Foods Inc    TSN            New York Stock     Mid Value
#  24                      NaN    NaN            Exchange, Inc.           NaN
#  25             Unilever PLC   ULVR     London Stock Exchange   Large Value
#  26                      NaN    NaN                       NaN           NaN
#  27             Unilever PLC     UL            New York Stock   Large Value
#  28                      NaN    NaN            Exchange, Inc.           NaN
#  29     United Natural Foods   UNFI            New York Stock   Small Value
#  30                      Inc    NaN            Exchange, Inc.           NaN
#
#         Food, Beverage &             Foods
#  0               Tobacco               NaN
#  1      Food, Beverage &    Beverage: Soft
#  2               Tobacco            drinks
#  3   Personal Care, Drug     Personal care
#  4      & Grocery Stores               NaN
#  5   Personal Care, Drug  Drug and grocery
#  6      & Grocery Stores      store chains
#  7   Personal Care, Drug     Personal care
#  8      & Grocery Stores               NaN
#  9   Personal Care, Drug  Drug and grocery
#  10     & Grocery Stores      store chains
#  11  Personal Care, Drug  Drug and grocery
#  12     & Grocery Stores      store chains
#  13  Personal Care, Drug  Drug and grocery
#  14     & Grocery Stores      store chains
#  15     Food, Beverage &             Foods
#  16              Tobacco               NaN
#  17     Food, Beverage &             Foods
#  18              Tobacco               NaN
#  19     Food, Beverage &             Foods
#  20              Tobacco               NaN
#  21     Food, Beverage &             Foods
#  22              Tobacco               NaN
#  23     Food, Beverage &             Foods
#  24              Tobacco               NaN
#  25  Personal Care, Drug     Personal care
#  26     & Grocery Stores               NaN
#  27  Personal Care, Drug     Personal care
#  28     & Grocery Stores               NaN
#  29     Food, Beverage &             Foods
#  30              Tobacco               NaN  ,
#                   Unnamed: 0 Unnamed: 1                Unnamed: 2  \
#  0               PepsiCo Inc        PEP                    Nasdaq
#  1                       NaN        NaN                       NaN
#  2       Procter & Gamble Co         PG            New York Stock
#  3                       NaN        NaN            Exchange, Inc.
#  4          Raia Drogasil SA      RADL3  B3 S.A. - Brasil, Bolsa,
#  5                       NaN        NaN                    Balcão
#  6         Reckitt Benckiser        RB.     London Stock Exchange
#  7                 Group PLC        NaN                       NaN
#  8             Rite Aid Corp        RAD            New York Stock
#  9                       NaN        NaN            Exchange, Inc.
#  10        Sainsbury (J) PLC       SBRY     London Stock Exchange
#  11                      NaN        NaN                       NaN
#  12          Sprouts Farmers        SFM                    Nasdaq
#  13               Market Inc        NaN                       NaN
#  14               Sysco Corp        SYY            New York Stock
#  15                      NaN        NaN            Exchange, Inc.
#  16            "e Hershey Co        HSY            New York Stock
#  17                      NaN        NaN            Exchange, Inc.
#  18  Tootsie Roll Industries         TR            New York Stock
#  19                      Inc        NaN            Exchange, Inc.
#  20      Treehouse Foods Inc        THS            New York Stock
#  21                      NaN        NaN            Exchange, Inc.
#  22          Tyson Foods Inc        TSN            New York Stock
#  23                      NaN        NaN            Exchange, Inc.
#  24             Unilever PLC       ULVR     London Stock Exchange
#  25                      NaN        NaN                       NaN
#  26             Unilever PLC         UL            New York Stock
#  27                      NaN        NaN            Exchange, Inc.
#  28     United Natural Foods       UNFI            New York Stock
#  29                      Inc        NaN            Exchange, Inc.
#
#        Unnamed: 3              Tobacco        Unnamed: 4  \
#  0    Large Value     Food, Beverage &    Beverage: Soft
#  1            NaN              Tobacco            drinks
#  2    Large Value  Personal Care, Drug     Personal care
#  3            NaN     & Grocery Stores               NaN
#  4   Large Growth  Personal Care, Drug  Drug and grocery
#  5            NaN     & Grocery Stores      store chains
#  6    Large Blend  Personal Care, Drug     Personal care
#  7            NaN     & Grocery Stores               NaN
#  8    Small Value  Personal Care, Drug  Drug and grocery
#  9            NaN     & Grocery Stores      store chains
#  10     Mid Value  Personal Care, Drug  Drug and grocery
#  11           NaN     & Grocery Stores      store chains
#  12   Small Blend  Personal Care, Drug  Drug and grocery
#  13           NaN     & Grocery Stores      store chains
#  14   Large Value     Food, Beverage &             Foods
#  15           NaN              Tobacco               NaN
#  16   Large Blend     Food, Beverage &             Foods
#  17           NaN              Tobacco               NaN
#  18   Small Blend     Food, Beverage &             Foods
#  19           NaN              Tobacco               NaN
#  20   Small Value     Food, Beverage &             Foods
#  21           NaN              Tobacco               NaN
#  22     Mid Value     Food, Beverage &             Foods
#  23           NaN              Tobacco               NaN
#  24   Large Value  Personal Care, Drug     Personal care
#  25           NaN     & Grocery Stores               NaN
#  26   Large Value  Personal Care, Drug     Personal care
#  27           NaN     & Grocery Stores               NaN
#  28   Small Value     Food, Beverage &             Foods
#  29           NaN              Tobacco               NaN
#
#                Aemetis Inc    AMTX                    Nasdaq  Small Blend  \
#  0                  BP PLC      BP            New York Stock  Large Blend
#  1                     NaN     NaN            Exchange, Inc.          NaN
#  2             Cameco Corp     CCJ            New York Stock   Mid Growth
#  3                     NaN     NaN            Exchange, Inc.          NaN
#  4        Canadian Natural     CNQ    Toronto Stock Exchange  Large Value
#  5           Resources Ltd     NaN                       NaN          NaN
#  6            Chevron Corp     CVX            New York Stock  Large Blend
#  7                     NaN     NaN            Exchange, Inc.          NaN
#  8       China Petroleum &   00386       Hong Kong Exchanges  Large Value
#  9           Chemical Corp     NaN          And Clearing Ltd          NaN
#  10      China Petroleum &     SNP            New York Stock  Large Value
#  11          Chemical Corp     NaN            Exchange, Inc.          NaN
#  12              CNOOC Ltd     CEO            New York Stock  Large Blend
#  13                    NaN     NaN            Exchange, Inc.          NaN
#  14         Coal India Ltd  533278                   BSE LTD  Large Value
#  15                    NaN     NaN                       NaN          NaN
#  16  Continental Resources     CLR            New York Stock    Mid Value
#  17                    Inc     NaN            Exchange, Inc.          NaN
#  18               Cosan SA   CSAN3  B3 S.A. - Brasil, Bolsa,  Large Blend
#  19                    NaN     NaN                    Balcão          NaN
#  20     Energy Transfer LP      ET            New York Stock    Mid Value
#  21                    NaN     NaN            Exchange, Inc.          NaN
#  22       Exxon Mobil Corp     XOM            New York Stock  Large Value
#  23                    NaN     NaN            Exchange, Inc.          NaN
#  24           Glencore PLC    GLEN     London Stock Exchange  Large Blend
#  25                    NaN     NaN                       NaN          NaN
#  26              Hess Corp     HES            New York Stock    Mid Blend
#  27                    NaN     NaN            Exchange, Inc.          NaN
#  28           Lamprell PLC     LAM     London Stock Exchange  Small Value
#  29                    NaN     NaN                       NaN          NaN
#
#      Alternative Energy  Alternative energy
#  0        Non-renewable     Oil: Integrated
#  1               Energy                 NaN
#  2   Alternative Energy  Alternative energy
#  3                  NaN                 NaN
#  4        Non-renewable          Oil: Crude
#  5               Energy           producers
#  6        Non-renewable     Oil: Integrated
#  7               Energy                 NaN
#  8        Non-renewable     Oil: Integrated
#  9               Energy                 NaN
#  10       Non-renewable     Oil: Integrated
#  11              Energy                 NaN
#  12       Non-renewable          Oil: Crude
#  13              Energy           producers
#  14       Non-renewable                Coal
#  15              Energy                 NaN
#  16       Non-renewable          Oil: Crude
#  17              Energy           producers
#  18  Alternative Energy  Alternative energy
#  19                 NaN                 NaN
#  20       Non-renewable        Gas pipeline
#  21              Energy                 NaN
#  22       Non-renewable     Oil: Integrated
#  23              Energy                 NaN
#  24       Non-renewable                Coal
#  25              Energy                 NaN
#  26       Non-renewable     Oil: Integrated
#  27              Energy                 NaN
#  28    Energy Equipment  Oil well equipment
#  29          & Services        and services  ,
#           Unnamed: 0 Unnamed: 1 Unnamed: 2        EQUITY           RUSSELL  \
#  0      COMPANY NAME     TICKER   EXCHANGE         STYLE        SUB-SECTOR
#  1  Nestle India Ltd     500790    BSE LTD  Large Growth  Food, Beverage &
#  2               NaN        NaN        NaN           NaN           Tobacco
#
#    RUSSELL INDUST        ENERGY Unnamed: 3 Unnamed: 4   Unnamed: 5  \
#  0             RY           NaN        NaN        NaN       EQUITY
#  1          Foods  COMPANY NAME     TICKER   EXCHANGE        STYLE
#  2            NaN   Aemetis Inc       AMTX     Nasdaq  Small Blend
#
#             Unnamed: 6          Unnamed: 7
#  0             RUSSELL             RUSSELL
#  1          SUB-SECTOR            INDUSTRY
#  2  Alternative Energy  Alternative energy  ,
#           PetroChina Co Ltd   00857       Hong Kong Exchanges  Large Blend  \
#  0                      NaN     NaN          And Clearing Ltd          NaN
#  1        PetroChina Co Ltd     PTR            New York Stock  Large Blend
#  2                      NaN     NaN            Exchange, Inc.          NaN
#  3   Petroleo Brasileiro SA   PETR3  B3 S.A. - Brasil, Bolsa,  Large Value
#  4                Petrobras     NaN                    Balcão          NaN
#  5   Petroleo Brasileiro SA   PETR4  B3 S.A. - Brasil, Bolsa,  Large Value
#  6                Petrobras     NaN                    Balcão          NaN
#  7              Phillips 66     PSX            New York Stock  Large Value
#  8                      NaN     NaN            Exchange, Inc.          NaN
#  9      Reliance Industries  500325                   BSE LTD  Large Blend
#  10                     Ltd     NaN                       NaN          NaN
#  11   Royal Dutch Shell PLC    RDSA     London Stock Exchange  Large Blend
#  12                     NaN     NaN                       NaN          NaN
#  13                SJVN Ltd  533206                   BSE LTD    Mid Value
#
#           Non-renewable     Oil: Integrated
#  0               Energy                 NaN
#  1        Non-renewable     Oil: Integrated
#  2               Energy                 NaN
#  3        Non-renewable     Oil: Integrated
#  4               Energy                 NaN
#  5        Non-renewable     Oil: Integrated
#  6               Energy                 NaN
#  7        Non-renewable      Oil: Re!ning &
#  8               Energy           marketing
#  9        Non-renewable      Oil: Re!ning &
#  10              Energy           marketing
#  11       Non-renewable     Oil: Integrated
#  12              Energy                 NaN
#  13  Alternative Energy  Alternative energy  ,
#                    A$ac Inc     AFL            New York Stock    Large Value  \
#  0                      NaN     NaN            Exchange, Inc.            NaN
#  1            Allstate Corp     ALL            New York Stock    Large Value
#  2                      NaN     NaN            Exchange, Inc.            NaN
#  3      American Express Co     AXP            New York Stock    Large Blend
#  4                      NaN     NaN            Exchange, Inc.            NaN
#  5   Artisan Partners Asset    APAM            New York Stock    Small Value
#  6           Management Inc     NaN            Exchange, Inc.            NaN
#  7                      NaN     NaN                       NaN            NaN
#  8                Aviva PLC     AV.     London Stock Exchange      Mid Value
#  9                      NaN     NaN                       NaN            NaN
#  10           Axis Bank Ltd  532215                   BSE LTD    Large Blend
#  11    B3 SA - Brasil Bolsa   B3SA3  B3 S.A. - Brasil, Bolsa,   Large Growth
#  12                  Balcao     NaN                    Balcão            NaN
#  13                     NaN     NaN                       NaN            NaN
#  14       Bajaj Finserv Ltd  532978                   BSE LTD   Large Growth
#  15                     NaN     NaN                       NaN            NaN
#  16       Banco BTG Pactual  BPAC11  B3 S.A. - Brasil, Bolsa,  Not Available
#  17                    S.A.     NaN                    Balcão            NaN
#  18                     NaN     NaN                       NaN            NaN
#  19   Banco do Brasil SA BB   BBAS3  B3 S.A. - Brasil, Bolsa,    Large Value
#  20                  Brasil     NaN                    Balcão            NaN
#  21         Banco Santander  SANB11  B3 S.A. - Brasil, Bolsa,  Not Available
#  22             (Brasil) SA     NaN                    Balcão            NaN
#  23        Bank Bradesco SA   BBDC3  B3 S.A. - Brasil, Bolsa,    Large Value
#  24                     NaN     NaN                    Balcão            NaN
#  25        Bank Bradesco SA   BBDC4  B3 S.A. - Brasil, Bolsa,    Large Value
#  26                     NaN     NaN                    Balcão            NaN
#  27       Bank Of Ningbo Co  002142   Shenzhen Stock Exchange    Large Blend
#  28                     Ltd     NaN                       NaN            NaN
#  29     Bank of Nova Scotia     BNS    Toronto Stock Exchange    Large Value
#  30                Bank OZK     OZK                    Nasdaq    Small Blend
#  31            Barclays PLC     BCS            New York Stock    Large Value
#  32                     NaN     NaN            Exchange, Inc.            NaN
#
#              Insurance    Insurance: Life
#  0                 NaN                NaN
#  1           Insurance         Insurance:
#  2                 NaN  Property-casualty
#  3    Consumer Finance   Financial data &
#  4   & Credit Services            systems
#  5          Investment   Asset management
#  6           Banking &        & custodian
#  7           Brokerage                NaN
#  8           Insurance  Insurance: Multi-
#  9                 NaN               line
#  10              Banks  Banks: Diversi!ed
#  11         Investment         Securities
#  12          Banking &        brokerage &
#  13          Brokerage           services
#  14          Insurance  Insurance: Multi-
#  15                NaN               line
#  16         Investment         Diversi!ed
#  17          Banking &  !nancial services
#  18          Brokerage                NaN
#  19              Banks  Banks: Diversi!ed
#  20                NaN                NaN
#  21              Banks  Banks: Diversi!ed
#  22                NaN                NaN
#  23              Banks  Banks: Diversi!ed
#  24                NaN                NaN
#  25              Banks  Banks: Diversi!ed
#  26                NaN                NaN
#  27              Banks  Banks: Diversi!ed
#  28                NaN                NaN
#  29              Banks  Banks: Diversi!ed
#  30              Banks  Banks: Diversi!ed
#  31              Banks  Banks: Diversi!ed
#  32                NaN                NaN  ,
#     BR Malls Participacoes   BRML3  B3 S.A. - Brasil, Bolsa,      Mid Value  \
#  0                      SA     NaN                    Balcão            NaN
#  1        Canadian Western     CWB    Toronto Stock Exchange    Small Blend
#  2                    Bank     NaN                       NaN            NaN
#  3      China Construction   00939       Hong Kong Exchanges    Large Value
#  4               Bank Corp     NaN          And Clearing Ltd            NaN
#  5    China Finance Online    JRJC                    Nasdaq  Not Available
#  6                  Co Ltd     NaN                       NaN            NaN
#  7      China Vanke Co Ltd   02202       Hong Kong Exchanges    Large Blend
#  8                     NaN     NaN          And Clearing Ltd            NaN
#  9      China Vanke Co Ltd  000002   Shenzhen Stock Exchange    Large Blend
#  10                    NaN     NaN                       NaN            NaN
#  11      China World Trade  600007   Shanghai Stock Exchange      Mid Blend
#  12          Center Co Ltd     NaN                       NaN            NaN
#  13               Cielo SA   CIEL3  B3 S.A. - Brasil, Bolsa,      Mid Value
#  14                    NaN     NaN                    Balcão            NaN
#  15          Citigroup Inc       C            New York Stock    Large Value
#  16                    NaN     NaN            Exchange, Inc.            NaN
#  17                    NaN     NaN                       NaN            NaN
#  18         City of London    CLIG     London Stock Exchange    Small Value
#  19   Investment Group PLC     NaN                       NaN            NaN
#  20                    NaN     NaN                       NaN            NaN
#  21    Credit Suisse Group      CS            New York Stock    Large Value
#  22                     AG     NaN            Exchange, Inc.            NaN
#  23                    NaN     NaN                       NaN            NaN
#  24       Deutsche Bank AG      DB            New York Stock    Large Value
#
#            Real Estate  Real estate holding
#  0                 NaN      and development
#  1               Banks    Banks: Diversi!ed
#  2                 NaN                  NaN
#  3               Banks    Banks: Diversi!ed
#  4                 NaN                  NaN
#  5    Consumer Finance     Financial data &
#  6   & Credit Services              systems
# ...
#
#      Transportation &      Transportation
#  0            Freight       miscellaneous
#  1   Transportation &       Air transport
#  2            Freight                 NaN
#  3                NaN                 NaN
#  4   Transportation &       Air transport
#  5            Freight                 NaN
#  6    Manufacturing &          Diversi!ed
#  7         Production       manufacturing
#  8                NaN          operations
#  9          Machinery    Machinery: Tools
#  10               NaN                 NaN
#  11  Transportation &       Air transport
#  12           Freight                 NaN
#  13  Transportation &       Air transport
#  14           Freight                 NaN
#  15         Machinery          Machinery:
#  16               NaN          Industrial
#  17         Machinery          Machinery:
#  18               NaN        Agricultural
#  19        Commercial  Back o%ce support,
#  20          Services     HR & consulting
#  21  Transportation &          Commercial
#  22           Freight  vehicles and parts  ,
#                 Adobe Inc  ADBE          Nasdaq  Large Growth  Information  \
#  0                    NaN   NaN             NaN           NaN   Technology
#  1  Alibaba Group Holding  BABA  New York Stock  Large Growth  Information
#  2                    Ltd   NaN  Exchange, Inc.           NaN   Technology
#  3           Alphabet Inc  GOOG          Nasdaq  Large Growth  Information
#  4                    NaN   NaN             NaN           NaN   Technology
#
#        Computer services
#  0  software and systems
#  1     Computer services
#  2  software and systems
#  3     Computer services
#  4  software and systems  ,
#         Arista Networks Inc    ANET         New York Stock     Mid Growth  \
#  0                      NaN     NaN         Exchange, Inc.            NaN
#  1          Astra Microwave  532493                BSE LTD    Small Blend
#  2             Products Ltd     NaN                    NaN            NaN
#  3                Baidu Inc    BIDU                 Nasdaq  Not Available
#  4                      NaN     NaN                    NaN            NaN
#  5          Bene!tfocus Inc    BNFT                 Nasdaq   Small Growth
#  6                      NaN     NaN                    NaN            NaN
#  7     Cognizant Technology    CTSH                 Nasdaq    Large Blend
#  8           Solutions Corp     NaN                    NaN            NaN
#  9   Constellation Software     CSU          Toronto Stock   Large Growth
#  10                     Inc     NaN               Exchange            NaN
#  11    discoverIE Group PLC    DSCV  London Stock Exchange   Small Growth
#  12       DXC Technology Co     DXC         New York Stock      Mid Value
#  13                     NaN     NaN         Exchange, Inc.            NaN
#  14    Enghouse Systems Ltd    ENGH          Toronto Stock     Mid Growth
#  15                     NaN     NaN               Exchange            NaN
#  16            Facebook Inc      FB                 Nasdaq   Large Growth
#  17                     NaN     NaN                    NaN            NaN
#  18      Foxconn Industrial  601138         Shanghai Stock    Large Value
#  19         Internet Co Ltd     NaN               Exchange            NaN
#  20             Groupon Inc    GRPN                 Nasdaq    Small Value
#  21                     NaN     NaN                    NaN            NaN
#  22     Hangzhou Hik-Vision  002415         Shenzhen Stock    Large Blend
#  23   Digital Technology Co     NaN               Exchange            NaN
#  24                     Ltd     NaN                    NaN            NaN
#  25    HCL Technologies Ltd  532281                BSE LTD    Large Blend
#  26                     NaN     NaN                    NaN            NaN
#  27                Hexaware  532129                BSE LTD     Mid Growth
#  28        Technologies Ltd     NaN                    NaN            NaN
#  29             Infosys Ltd  500209                BSE LTD    Large Blend
#  30                     NaN     NaN                    NaN            NaN
#  31           Just Dial Ltd  535648                BSE LTD   Small Growth
#  32                     NaN     NaN                    NaN            NaN
#  33    Manhattan Associates    MANH                 Nasdaq      Mid Blend
#  34                     Inc     NaN                    NaN            NaN
#  35        Meituan Dianping   03690    Hong Kong Exchanges  Not Available
#  36                     NaN     NaN       And Clearing Ltd            NaN
#  37             Micro Focus    MCRO  London Stock Exchange    Small Value
#  38       International PLC     NaN                    NaN            NaN
#  39          Microsoft Corp    MSFT                 Nasdaq   Large Growth
#  40                     NaN     NaN                    NaN            NaN
#  41            MindTree Ltd  532819                BSE LTD      Mid Blend
#  42                     NaN     NaN                    NaN            NaN
#
#            Information     Computer services
#  0          Technology  software and systems
#  1   Telecommunication    Telecommunications
#  2                 NaN             equipment
#  3         Information     Computer services
#  4          Technology  software and systems
#  5         Information     Computer services
#  6          Technology  software and systems
#  7         Information     Computer services
#  8          Technology  software and systems
#  9         Information     Computer services
#  10         Technology  software and systems
#  11        Electronics           Electronics
#  12        Information     Computer services
#  13         Technology  software and systems
#  14        Information     Computer services
#  15         Technology  software and systems
#  16        Information     Computer services
#  17         Technology  software and systems
#  18  Telecommunication    Telecommunications
#  19                NaN             equipment
#  20        Information     Computer services
#  21         Technology  software and systems
#  22        Electronics            Electronic
#  23                NaN            components
#  24                NaN                   NaN
#  25        Information     Computer services
#  26         Technology  software and systems
#  27        Information     Computer services
#  28         Technology  software and systems
#  29        Information     Computer services
#  30         Technology  software and systems
#  31        Information     Computer services
#  32         Technology  software and systems
#  33        Information     Computer services
#  34         Technology  software and systems
#  35        Information     Computer services
#  36         Technology  software and systems
#  37        Information     Computer services
#  38         Technology  software and systems
#  39        Information     Computer services
#  40         Technology  software and systems
#  41        Information     Computer services
#  42         Technology  software and systems  ,
#           American Electric     AEP            New York Stock  Large Value  \
#  0             Power Co Inc     NaN            Exchange, Inc.          NaN
#  1           American Water     AWK            New York Stock    Mid Blend
#  2             Works Co Inc     NaN            Exchange, Inc.          NaN
#  3                 AT&T Inc       T            New York Stock  Large Value
#  4                      NaN     NaN            Exchange, Inc.          NaN
#  5                  BCE Inc     BCE    Toronto Stock Exchange  Large Blend
#  6                      NaN     NaN                       NaN          NaN
#  7        Bharti Airtel Ltd  532454                   BSE LTD  Large Value
#  8                      NaN     NaN                       NaN          NaN
#  9             BT Group PLC    BT.A     London Stock Exchange    Mid Value
#  10                     NaN     NaN                       NaN          NaN
#  11  Canadian Utilities Ltd      CU    Toronto Stock Exchange    Mid Blend
#  12                     NaN     NaN                       NaN          NaN
#  13      Centrais Eletricas   ELET3  B3 S.A. - Brasil, Bolsa,  Large Value
#  14          Brasileiras SA     NaN                    Balcão          NaN
#  15      Centrais Eletricas   ELET6  B3 S.A. - Brasil, Bolsa,  Large Value
#  16          Brasileiras SA     NaN                    Balcão          NaN
#  17      China Gas Holdings   00384       Hong Kong Exchanges  Large Blend
#  18                     Ltd     NaN          And Clearing Ltd          NaN
#  19        China Mobile Ltd   00941       Hong Kong Exchanges  Large Value
#  20                     NaN     NaN          And Clearing Ltd          NaN
#  21        China Mobile Ltd     CHL            New York Stock  Large Value
#  22                     NaN     NaN            Exchange, Inc.          NaN
#  23      China Telecom Corp     CHA            New York Stock  Large Value
#  24                     Ltd     NaN            Exchange, Inc.          NaN
#  25      China Unicom (Hong     CHU            New York Stock  Large Value
#  26               Kong) Ltd     NaN            Exchange, Inc.          NaN
#
#      Utilities  Utilities: Electrical
#  0         NaN                    NaN
#  1   Utilities       Utilities: Water
#  2         NaN                    NaN
#  3   Utilities             Utilities:
#  4         NaN     Telecommunications
#  5   Utilities             Utilities:
#  6         NaN     Telecommunications
#  7   Utilities             Utilities:
#  8         NaN     Telecommunications
#  9   Utilities             Utilities:
#  10        NaN     Telecommunications
#  11  Utilities             Utilities:
#  12        NaN          Miscellaneous
#  13  Utilities  Utilities: Electrical
#  14        NaN                    NaN
#  15  Utilities  Utilities: Electrical
#  16        NaN                    NaN
#  17  Utilities         Utilities: Gas
#  18        NaN           distributors
#  19  Utilities             Utilities:
#  20        NaN     Telecommunications
#  21  Utilities             Utilities:
#  22        NaN     Telecommunications
#  23  Utilities             Utilities:
#  24        NaN     Telecommunications
#  25  Utilities             Utilities:
#  26        NaN     Telecommunications  ,
#       ENGIE Brasil Energia   EGIE3  B3 S.A. - Brasil, Bolsa,   Large Blend  \
#  0                      SA     NaN                    Balcão           NaN
#  1   Equatorial Energia SA   EQTL3  B3 S.A. - Brasil, Bolsa,  Large Growth
#  2                     NaN     NaN                    Balcão           NaN
#  3        FirstEnergy Corp      FE            New York Stock     Mid Value
#  4                     NaN     NaN            Exchange, Inc.           NaN
#  5        GAIL (India) Ltd  532155                   BSE LTD   Large Value
#  6                     NaN     NaN                       NaN           NaN
#  7                Gogo Inc    GOGO                    Nasdaq   Small Blend
#  8                     NaN     NaN                       NaN           NaN
#  9      GTT Communications     GTT            New York Stock   Small Blend
#  10                    Inc     NaN            Exchange, Inc.           NaN
#  11     Gujarat Industries  517300                   BSE LTD   Small Value
#  12           Power Co Ltd     NaN                       NaN           NaN
#  13          Huaneng Power     HNP            New York Stock   Large Value
#  14      International Inc     NaN            Exchange, Inc.           NaN
#  15    Mahanagar Telephone  500108                   BSE LTD   Small Value
#  16              Nigam Ltd     NaN                       NaN           NaN
#  17     Middlesex Water Co    MSEX                    Nasdaq   Small Blend
#  18   National Fuel Gas Co     NFG            New York Stock   Small Value
#  19                    NaN     NaN            Exchange, Inc.           NaN
#  20               NTPC Ltd  532555                   BSE LTD   Large Value
#  21              PG&E Corp     PCG            New York Stock     Mid Value
#  22                    NaN     NaN            Exchange, Inc.           NaN
#  23     Power Grid Corp Of  532898                   BSE LTD   Large Value
#  24              India Ltd     NaN                       NaN           NaN
#  25          Sempra Energy     SRE            New York Stock   Large Value
#  26                    NaN     NaN            Exchange, Inc.           NaN
#  27       Severn Trent PLC     SVT     London Stock Exchange     Mid Value
#  28              SJW Group     SJW            New York Stock   Small Blend
#  29                    NaN     NaN            Exchange, Inc.           NaN
#  30            Southern Co      SO            New York Stock   Large Value
#  31                    NaN     NaN            Exchange, Inc.           NaN
#  32                SSE PLC     SSE     London Stock Exchange   Large Value
#  33      Tata Power Co Ltd  500400                   BSE LTD     Mid Value
#  34   Telefonica Brasil SA   VIVT4  B3 S.A. - Brasil, Bolsa,   Large Value
#  35                    NaN     NaN                    Balcão           NaN
#  36       "e York Water Co    YORW                    Nasdaq   Small Blend
#
#      Utilities  Utilities: Electrical
#  0         NaN                    NaN
#  1   Utilities  Utilities: Electrical
#  2         NaN                    NaN
#  3   Utilities  Utilities: Electrical
#  4         NaN                    NaN
#  5   Utilities         Utilities: Gas
#  6         NaN           distributors
#  7   Utilities             Utilities:
#  8         NaN     Telecommunications
#  9   Utilities             Utilities:
#  10        NaN     Telecommunications
#  11  Utilities  Utilities: Electrical
#  12        NaN                    NaN
#  13  Utilities  Utilities: Electrical
#  14        NaN                    NaN
#  15  Utilities             Utilities:
#  16        NaN     Telecommunications
#  17  Utilities       Utilities: Water
#  18  Utilities         Utilities: Gas
#  19        NaN           distributors
#  20  Utilities  Utilities: Electrical
#  21  Utilities  Utilities: Electrical
#  22        NaN                    NaN
#  23  Utilities  Utilities: Electrical
#  24        NaN                    NaN
#  25  Utilities             Utilities:
#  26        NaN          Miscellaneous
#  27  Utilities       Utilities: Water
#  28  Utilities       Utilities: Water
#  29        NaN                    NaN
#  30  Utilities  Utilities: Electrical
#  31        NaN                    NaN
#  32  Utilities  Utilities: Electrical
#  33  Utilities  Utilities: Electrical
#  34  Utilities             Utilities:
#  35        NaN     Telecommunications
#  36  Utilities       Utilities: Water  ,
#                 Unnamed: 0 Unnamed: 1             Unnamed: 2       EQUITY  \
#  0            COMPANY NAME     TICKER               EXCHANGE        STYLE
#  1  United Utilities Group        UU.  London Stock Exchange    Mid Value
#  2                     PLC        NaN                    NaN          NaN
#  3                 Verizon         VZ         New York Stock  Large Value
#  4      Communications Inc        NaN         Exchange, Inc.          NaN
#  5      Vodafone Group PLC        VOD  London Stock Exchange  Large Value
#  6                     NaN        NaN                    NaN          NaN
#  7      Vodafone Group PLC        VOD                 Nasdaq  Large Value
#
#        RUSSELL          Unnamed: 3
#  0  SUB-SECTOR    RUSSELL INDUSTRY
#  1   Utilities    Utilities: Water
#  2         NaN                 NaN
#  3   Utilities          Utilities:
#  4         NaN  Telecommunications
#  5   Utilities          Utilities:
#  6         NaN  Telecommunications
#  7   Utilities          Utilities:  ]

# %%
#Get the list of columns in each of the dataframes 
columns_list = get_column_list(df)

# %%
columns_list
# Out:
# [['Abercrombie & Fitch',
#   'ANF',
#   'New York Stock',
#   'Small Value',
#   'Retail',
#   'Specialty retail'],
#  ['China Tourism Group',
#   '601888',
#   'Shanghai Stock Exchange',
#   'Large Growth',
#   'Leisure',
#   'Hotel/motel'],
#  ['Imax Corp',
#   'IMAX',
#   'New York Stock',
#   'Small Growth',
#   'Media',
#   'Entertainment'],
#  ['Nike Inc',
#   'NKE',
#   'New York Stock',
#   'Large Growth',
#   'Consumer Products',
#   'Textiles apparel'],
#  ['Colgate-Palmolive Co',
#   'CL',
#   'New York Stock',
#   'Large Value',
#   'Personal Care, Drug',
#   'Personal care'],
#  ['Nestle India Ltd',
#   '500790',
#   'BSE LTD',
#   'Large Growth',
#   'Food, Beverage &',
#   'Foods'],
#  ['Unnamed: 0',
#   'Unnamed: 1',
#   'Unnamed: 2',
#   'Unnamed: 3',
#   'Tobacco',
#   'Unnamed: 4',
#   'Aemetis Inc',
#   'AMTX',
#   'Nasdaq',
#   'Small Blend',
#   'Alternative Energy',
#   'Alternative energy'],
#  ['Unnamed: 0',
#   'Unnamed: 1',
#   'Unnamed: 2',
#   'EQUITY',
#   'RUSSELL',
#   'RUSSELL INDUST',
#   'ENERGY',
#   'Unnamed: 3',
#   'Unnamed: 4',
#   'Unnamed: 5',
#   'Unnamed: 6',
#   'Unnamed: 7'],
#  ['PetroChina Co Ltd',
#   '00857',
#   'Hong Kong Exchanges',
#   'Large Blend',
#   'Non-renewable',
#   'Oil: Integrated'],
#  ['A$ac Inc',
#   'AFL',
#   'New York Stock',
#   'Large Value',
#   'Insurance',
#   'Insurance: Life'],
#  ['BR Malls Participacoes',
#   'BRML3',
#   'B3 S.A. - Brasil, Bolsa,',
#   'Mid Value',
#   'Real Estate',
#   'Real estate holding'],
#  ['Max Financial Services',
#   '500271',
#   'BSE LTD',
#   'Mid Blend',
#   'Insurance',
#   'Insurance: Life'],
#  ['Sul America SA',
#   'SULA11',
#   'B3 S.A. - Brasil, Bolsa,',
#   'Not Available',
#   'Insurance',
#   'Insurance: Multi-'],
#  ['Cardiovascular',
#   'CSII',
#   'Nasdaq',
#   'Small Growth',
#   'Medical Equipment',
#   'Medical & dental'],
#  ['Regeneron',
#   'REGN',
#   'Nasdaq',
#   'Large Growth',
#   'Pharmaceuticals &',
#   'Biotechnology'],
#  ['Anhui Conch Cement',
#   '600585',
#   'Shanghai Stock Exchange',
#   'Large Blend',
#   'Building Materials',
#   'Cement'],
#  ['Freeport-McMoRan',
#   'FCX',
#   'New York Stock',
#   'Mid Blend',
#   'Metals & Minerals',
#   'Copper'],
#  ['China Eastern Airlines',
#   'CEA',
#   'New York Stock',
#   'Large Value',
#   'Transportation &',
#   'Air transport'],
#  ['Rumo SA',
#   'RAIL3',
#   'B3 S.A. - Brasil, Bolsa,',
#   'Large Growth',
#   'Transportation &',
#   'Transportation'],
#  ['Adobe Inc',
#   'ADBE',
#   'Nasdaq',
#   'Large Growth',
#   'Information',
#   'Computer services'],
#  ['Arista Networks Inc',
#   'ANET',
#   'New York Stock',
#   'Mid Growth',
#   'Information',
#   'Computer services'],
#  ['American Electric',
#   'AEP',
#   'New York Stock',
#   'Large Value',
#   'Utilities',
#   'Utilities: Electrical'],
#  ['ENGIE Brasil Energia',
#   'EGIE3',
#   'B3 S.A. - Brasil, Bolsa,',
#   'Large Blend',
#   'Utilities',
#   'Utilities: Electrical'],
#  ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'EQUITY', 'RUSSELL', 'Unnamed: 3']]

# %% [markdown]
# #### Because Tabula outputs messy data for this pdf, we will need to:
#     1. Turn each dataframe into a list of pandas series objects to remove the columns (We only want one column)
#     2. Use pd.concat to rebuild the series objects into pandas objects with only one column
#
# ##### The cell below turns each dataframe into a list of series.

# %%
series_list = [get_series_list(df[x], columns_list[x]) for x in range(len(df))]
series_list
# Out:
# [[0                        Co
#   1       Acorn International
#   2                       Inc
#   3            Amazon.com Inc
#   4            American Eagle
#   5             Out!tters Inc
#   6                 Aptiv PLC
#   8         Avon Products Inc
#   10          B2W - Companhia
#   11                  Digital
#   12           Bajaj Auto Ltd
#   14           Barnes & Noble
#   15            Education Inc
#   16           Bata India Ltd
#   18        Bed Bath & Beyond
#   19                      Inc
#   20          Best Buy Co Inc
#   22           BorgWarner Inc
#   24                Bosch Ltd
#   25      Boyd Group Services
#   26                      Inc
#   27             Build-A-Bear
#   28             Workshop Inc
#   29    Burlington Stores Inc
#   31             Canada Goose
#   32             Holdings Inc
#   33               CarMax Inc
#   35             Carnival PLC
#   36       Cheesecake Factory
#   37                      Inc
#   38         China Automotive
#   39              Systems Inc
#   Name: Abercrombie & Fitch, dtype: object, 1        ATV
#   3       AMZN
#   4        AEO
#   6       APTV
#   8        AVP
#   10     BTOW3
#   12    532977
#   14      BNED
#   16    500043
#   18      BBBY
#   20       BBY
#   22       BWA
#   24    500530
#   25       BYD
#   27       BBW
#   29      BURL
#   31      GOOS
#   33       KMX
#   35       CCL
#   36      CAKE
#   38      CAAS
#   Name: ANF, dtype: object, 0               Exchange, Inc.
#   1               New York Stock
#   2               Exchange, Inc.
#   3                       Nasdaq
#   4               New York Stock
#   5               Exchange, Inc.
#   6               New York Stock
#   7               Exchange, Inc.
#   8               New York Stock
#   9               Exchange, Inc.
#   10    B3 S.A. - Brasil, Bolsa,
#   11                      Balcão
#   12                     BSE LTD
#   14              New York Stock
#   15              Exchange, Inc.
#   16                     BSE LTD
#   18                      Nasdaq
#   20              New York Stock
#   21              Exchange, Inc.
#   22              New York Stock
#   23              Exchange, Inc.
#   24                     BSE LTD
#   25      Toronto Stock Exchange
#   27              New York Stock
#   28              Exchange, Inc.
#   29              New York Stock
#   30              Exchange, Inc.
#   31      Toronto Stock Exchange
#   33              New York Stock
#   34              Exchange, Inc.
#   35       London Stock Exchange
#   36                      Nasdaq
#   38                      Nasdaq
#   Name: New York Stock, dtype: object, 1     Not Available
#   3      Large Growth
#   4       Small Value
#   6        Mid Growth
#   8      Small Growth
#   10     Large Growth
#   12      Large Blend
#   14      Small Blend
#   16       Mid Growth
#   18      Small Value
#   20        Mid Value
#   22        Mid Value
#   24      Large Value
#   25       Mid Growth
#   27      Small Value
#   29       Mid Growth
#   31       Mid Growth
#   33       Mid Growth
#   35      Small Value
#   36      Small Value
#   38      Small Value
#   Name: Small Value, dtype: object, 1                 Media
#   3                Retail
#   4                Retail
#   6     Auto & Auto Parts
#   8     Consumer Products
#   10               Retail
#   12              Leisure
#   14               Retail
#   16    Consumer Products
#   18               Retail
#   20               Retail
#   22    Auto & Auto Parts
#   24    Auto & Auto Parts
#   25    Auto & Auto Parts
#   27               Retail
#   29               Retail
#   31    Consumer Products
#   33               Retail
#   35              Leisure
#   36              Leisure
#   38    Auto & Auto Parts
#   Name: Retail, dtype: object, 1            Advertising
#   2               agencies
#   3      Diversi!ed retail
#   4       Specialty retail
#   6             Auto parts
#   8              Cosmetics
#   10     Diversi!ed retail
#   12          Recreational
#   13    vehicles and boats
#   14      Specialty retail
#   16      Textiles apparel
#   17             and shoes
#   18      Specialty retail
#   20      Specialty retail
#   22            Auto parts
#   24            Auto parts
#   25         Auto services
#   27      Specialty retail
#   29      Specialty retail
#   31      Textiles apparel
#   32             and shoes
#   33      Specialty retail
#   35          Leisure time
#   36           Restaurants
#   38            Auto parts
#   Name: Specialty retail, dtype: object], [0         Duty Free Corp Ltd
#   1     Chipotle Mexican Grill
#   2                        Inc
#   3               Comcast Corp
#   5          Compass Group PLC
#   7          Core-Mark Holding
#   8                     Co Inc
#   9           Costco Wholesale
#   10                      Corp
#   11        Daily Journal Corp
#   12       Dollar General Corp
#   14           Dollar Tree Inc
#   15             Dollarama Inc
#   16        Domino’s Pizza Inc
#   18           Foot Locker Inc
#   20             Ford Motor Co
#   22                   Gap Inc
#   24         General Motors Co
#   26             H&R Block Inc
#   28       Harley-Davidson Inc
#   30                Hasbro Inc
#   31         Hero MotoCorp Ltd
#   33        Hibbett Sports Inc
#   34        Honda Motor Co Ltd
#   36         Hostelworld Group
#   37                       PLC
#   38         Hyatt Hotels Corp
#   Name: China Tourism Group, dtype: object, 1        CMG
#   3      CMCSA
#   5        CPG
#   7       CORE
#   9       COST
#   11      DJCO
#   12        DG
#   14      DLTR
#   15       DOL
#   16       DPZ
#   18        FL
#   20         F
#   22       GPS
#   24        GM
#   26       HRB
#   28       HOG
#   30       HAS
#   31    500182
#   33      HIBB
#   34       HMC
#   36       HSW
#   38         H
#   Name: 601888, dtype: object, 1             New York Stock
#   2             Exchange, Inc.
#   3                     Nasdaq
#   5      London Stock Exchange
#   7                     Nasdaq
#   9                     Nasdaq
#   11                    Nasdaq
#   12            New York Stock
#   13            Exchange, Inc.
#   14                    Nasdaq
#   15    Toronto Stock Exchange
#   16            New York Stock
#   17            Exchange, Inc.
#   18            New York Stock
#   19            Exchange, Inc.
#   20            New York Stock
#   21            Exchange, Inc.
#   22            New York Stock
#   23            Exchange, Inc.
#   24            New York Stock
#   25            Exchange, Inc.
#   26            New York Stock
#   27            Exchange, Inc.
#   28            New York Stock
#   29            Exchange, Inc.
#   30                    Nasdaq
#   31                   BSE LTD
#   33                    Nasdaq
#   34            New York Stock
#   35            Exchange, Inc.
#   36     London Stock Exchange
#   38            New York Stock
#   39            Exchange, Inc.
#   Name: Shanghai Stock Exchange, dtype: object, 1     Large Growth
#   3      Large Value
#   5      Large Blend
#   7      Small Blend
#   9      Large Blend
#   11    Small Growth
#   12     Large Blend
#   14       Mid Blend
#   15      Mid Growth
#   16      Mid Growth
#   18     Small Blend
#   20     Large Value
#   22       Mid Value
#   24     Large Blend
#   26     Small Value
#   28     Small Value
#   30       Mid Blend
#   31     Large Value
#   33     Small Blend
#   34     Large Value
#   36     Small Value
#   38       Mid Blend
#   Name: Large Growth, dtype: object, 1               Leisure
#   3                 Media
#   5     Consumer Services
#   7                Retail
#   9                Retail
#   11                Media
#   12               Retail
#   14               Retail
#   15               Retail
#   16              Leisure
#   18               Retail
#   20    Auto & Auto Parts
#   22               Retail
#   24    Auto & Auto Parts
#   26    Consumer Services
#   28              Leisure
#   30    Consumer Products
#   31              Leisure
#   33               Retail
#   34    Auto & Auto Parts
#   36              Leisure
#   38              Leisure
#   Name: Leisure, dtype: object, 1            Restaurants
#   3       Cable television
#   4               services
#   5            Vending and
#   6      catering services
#   7      Diversi!ed retail
#   9      Diversi!ed retail
#   11            Publishing
#   12     Diversi!ed retail
#   14     Diversi!ed retail
#   15     Diversi!ed retail
#   16           Restaurants
#   18      Specialty retail
#   20           Automobiles
#   22      Specialty retail
#   24           Automobiles
#   26    Consumer services:
#   27         Miscellaneous
#   28          Recreational
#   29    vehicles and boats
#   30                  Toys
#   31          Recreational
#   32    vehicles and boats
#   33      Specialty retail
#   34           Automobiles
#   36          Leisure time
#   38           Hotel/motel
#   Name: Hotel/motel, dtype: object], [1           InterContinental
#   2           Hotels Group PLC
#   3         Jubilant Foodworks
#   4                        Ltd
#   5             Lands’ End Inc
#   6       Las Vegas Sands Corp
#   8         LCI Industries Inc
#   10    Localiza Rent A Car SA
#   12       Lojas Americanas SA
#   14           Lojas Renner SA
#   16               Lookers PLC
#   17       Lululemon Athletica
#   18                       Inc
#   19                  Lyft Inc
#   21                Macy’s Inc
#   23         Magazine Luiza SA
#   25       Mahindra & Mahindra
#   26                       Ltd
#   27    Marriott International
#   28                       Inc
#   29       Maruti Suzuki India
#   30                       Ltd
#   31                Mattel Inc
#   32           McDonald’s Corp
#   34        Midea Group Co Ltd
#   36          Movado Group Inc
#   38              New Oriental
#   39               Education &
#   40      Technology Group Inc
#   41                  Next PLC
#   Name: Imax Corp, dtype: object, 1        IHG
#   3     533155
#   5         LE
#   6        LVS
#   8       LCII
#   10     RENT3
#   12     LAME4
#   14     LREN3
#   16      LOOK
#   17      LULU
#   19      LYFT
#   21         M
#   23     MGLU3
#   25    500520
#   27       MAR
#   29    532500
#   31       MAT
#   32       MCD
#   34    000333
#   36       MOV
#   38       EDU
#   41       NXT
#   Name: IMAX, dtype: object, 0               Exchange, Inc.
#   1        London Stock Exchange
#   3                      BSE LTD
#   5                       Nasdaq
#   6               New York Stock
#   7               Exchange, Inc.
#   8               New York Stock
#   9               Exchange, Inc.
#   10    B3 S.A. - Brasil, Bolsa,
#   11                      Balcão
#   12    B3 S.A. - Brasil, Bolsa,
#   13                      Balcão
#   14    B3 S.A. - Brasil, Bolsa,
#   15                      Balcão
#   16       London Stock Exchange
#   17                      Nasdaq
#   19                      Nasdaq
#   21              New York Stock
#   22              Exchange, Inc.
#   23    B3 S.A. - Brasil, Bolsa,
#   24                      Balcão
#   25                     BSE LTD
#   27                      Nasdaq
#   29                     BSE LTD
#   31                      Nasdaq
#   32              New York Stock
#   33              Exchange, Inc.
#   34     Shenzhen Stock Exchange
#   36              New York Stock
#   37              Exchange, Inc.
#   38              New York Stock
#   39              Exchange, Inc.
#   41       London Stock Exchange
#   Name: New York Stock, dtype: object, 1         Mid Blend
#   3        Mid Growth
#   5       Small Blend
#   6       Large Value
#   8      Small Growth
#   10     Large Growth
#   12     Large Growth
#   14     Large Growth
#   16      Small Value
#   17     Large Growth
#   19    Not Available
#   21      Small Value
#   23     Large Growth
#   25      Large Blend
#   27      Large Value
#   29      Large Blend
#   31      Small Blend
#   32      Large Blend
#   34      Large Blend
#   36      Small Value
#   38    Not Available
#   41        Mid Blend
#   Name: Small Growth, dtype: object, 1               Leisure
#   3               Leisure
#   5                Retail
#   6               Leisure
#   8               Leisure
#   10    Consumer Services
#   12               Retail
#   14               Retail
#   16               Retail
#   17    Consumer Products
#   19    Consumer Services
#   21               Retail
#   23               Retail
#   25    Auto & Auto Parts
#   27              Leisure
#   29    Auto & Auto Parts
#   31    Consumer Products
#   32              Leisure
#   34    Consumer Products
#   36    Consumer Products
#   38    Consumer Services
#   41               Retail
#   Name: Media, dtype: object, 1            Hotel/motel
#   3            Restaurants
#   5      Diversi!ed retail
#   6            Casinos and
#   7               gambling
#   8           Recreational
#   9     vehicles and boats
#   10    Rental and leasing
#   11    services: Consumer
#   12     Diversi!ed retail
#   14     Diversi!ed retail
#   16      Specialty retail
#   17      Textiles apparel
#   18             and shoes
#   19    Consumer services:
#   20         Miscellaneous
#   21     Diversi!ed retail
#   23     Diversi!ed retail
#   25           Automobiles
#   27           Hotel/motel
#   29           Automobiles
#   31                  Toys
#   32           Restaurants
#   34             Household
#   35            appliances
#   36          Luxury items
#   38    Education services
#   41     Diversi!ed retail
#   Name: Entertainment, dtype: object], [1     Norwegian Cruise Line
#   2              Holdings Ltd
#   3         On "e Beach Group
#   4                       PLC
#   5               Papa John’s
#   6         International Inc
#   7               Pearson PLC
#   8        Planet Fitness Inc
#   10     Red Lion Hotels Corp
#   12        Restaurant Brands
#   13        International Inc
#   14               Revlon Inc
#   16             Ritchie Bros
#   17          Auctioneers Inc
#   18       Sirius XM Holdings
#   19                      Inc
#   20           Smith & Wesson
#   21               Brands Inc
#   22           Starbucks Corp
#   23           Stitch Fix Inc
#   24      Tailored Brands Inc
#   26      TAL Education Group
#   28              Target Corp
#   30          Tata Motors Ltd
#   31                Tesla Inc
#   32      Texas Roadhouse Inc
#   33       "e Container Store
#   34                Group Inc
#   35          "e Estee Lauder
#   36            Companies Inc
#   37        "e Walt Disney Co
#   39            "e Wendy’s Co
#   40              Ti#any & Co
#   Name: Nike Inc, dtype: object, 1       NCLH
#   3        OTB
#   5       PZZA
#   7       PSON
#   8       PLNT
#   10       RLH
#   12       QSR
#   14       REV
#   16       RBA
#   18      SIRI
#   20      SWBI
#   22      SBUX
#   23      SFIX
#   24      TLRD
#   26       TAL
#   28       TGT
#   30    500570
#   31      TSLA
#   32      TXRH
#   33       TCS
#   35        EL
#   37       DIS
#   39       WEN
#   40       TIF
#   Name: NKE, dtype: object, 0             Exchange, Inc.
#   1             New York Stock
#   2             Exchange, Inc.
#   3      London Stock Exchange
#   5                     Nasdaq
#   7      London Stock Exchange
#   8             New York Stock
#   9             Exchange, Inc.
#   10            New York Stock
#   11            Exchange, Inc.
#   12    Toronto Stock Exchange
#   14            New York Stock
#   15            Exchange, Inc.
#   16            New York Stock
#   17            Exchange, Inc.
#   18                    Nasdaq
#   20                    Nasdaq
#   22                    Nasdaq
#   23                    Nasdaq
#   24            New York Stock
#   25            Exchange, Inc.
#   26            New York Stock
#   27            Exchange, Inc.
#   28            New York Stock
#   29            Exchange, Inc.
#   30                   BSE LTD
#   31                    Nasdaq
#   32                    Nasdaq
#   33            New York Stock
#   34            Exchange, Inc.
#   35            New York Stock
#   36            Exchange, Inc.
#   37            New York Stock
#   38            Exchange, Inc.
#   39                    Nasdaq
#   40            New York Stock
#   41            Exchange, Inc.
#   Name: New York Stock, dtype: object, 1         Mid Blend
#   3      Small Growth
#   5      Small Growth
#   7         Mid Value
#   8        Mid Growth
#   10      Small Blend
#   12      Large Blend
#   14      Small Value
#   16       Mid Growth
#   18      Large Blend
#   20      Small Blend
#   22      Large Blend
#   23     Small Growth
#   24      Small Value
#   26    Not Available
#   28      Large Blend
#   30      Large Value
#   31     Large Growth
#   32     Small Growth
#   33      Small Value
#   35      Large Blend
#   37      Large Blend
#   39        Mid Blend
#   40        Mid Blend
#   Name: Large Growth, dtype: object, 1               Leisure
#   3               Leisure
#   5               Leisure
#   7     Consumer Services
#   8               Leisure
#   10              Leisure
#   12              Leisure
#   14    Consumer Products
#   16    Consumer Services
#   18                Media
#   20              Leisure
#   22              Leisure
#   23               Retail
#   24               Retail
#   26    Consumer Services
#   28               Retail
#   30    Auto & Auto Parts
#   31    Auto & Auto Parts
#   32              Leisure
#   33               Retail
#   35    Consumer Products
#   37                Media
#   39              Leisure
#   40    Consumer Products
#   Name: Consumer Products, dtype: object, 0              and shoes
#   1           Leisure time
#   3           Leisure time
#   5            Restaurants
#   7     Education services
#   8           Leisure time
#   10           Hotel/motel
#   12           Restaurants
#   14             Cosmetics
#   16    Consumer services:
#   17         Miscellaneous
#   18          Radio and TV
#   19          broadcasters
#   20          Leisure time
#   22           Restaurants
#   23     Diversi!ed retail
#   24      Specialty retail
#   26    Education services
#   28     Diversi!ed retail
#   30           Automobiles
#   31           Automobiles
#   32           Restaurants
#   33      Specialty retail
#   35             Cosmetics
#   37         Entertainment
#   39           Restaurants
#   40          Luxury items
#   Name: Textiles apparel, dtype: object], [1     Companhia Brasileira
#   2          De Distribuicao
#   3              Corteva Inc
#   5          CVS Health Corp
#   7        General Mills Inc
#   9       Godrej Agrovet Ltd
#   11         Godrej Consumer
#   12            Products Ltd
#   13      Hindustan Unilever
#   14                     Ltd
#   15                 ITC Ltd
#   Name: Colgate-Palmolive Co, dtype: object, 1      PCAR4
#   3       CTVA
#   5        CVS
#   7        GIS
#   9     540743
#   11    532424
#   13    500696
#   15    500875
#   Name: CL, dtype: object, 0               Exchange, Inc.
#   1     B3 S.A. - Brasil, Bolsa,
#   2                       Balcão
#   3               New York Stock
#   4               Exchange, Inc.
#   5               New York Stock
#   6               Exchange, Inc.
#   7               New York Stock
#   8               Exchange, Inc.
#   9                      BSE LTD
#   11                     BSE LTD
#   13                     BSE LTD
#   15                     BSE LTD
#   Name: New York Stock, dtype: object, 1         Mid Value
#   3     Not Available
#   5       Large Value
#   7       Large Value
#   9         Mid Blend
#   11      Large Blend
#   13     Large Growth
#   15      Large Blend
#   Name: Large Value, dtype: object, 0        & Grocery Stores
#   1     Personal Care, Drug
#   2        & Grocery Stores
#   3        Food, Beverage &
#   4                 Tobacco
#   5     Personal Care, Drug
#   6        & Grocery Stores
#   7        Food, Beverage &
#   8                 Tobacco
#   9        Food, Beverage &
#   10                Tobacco
#   11    Personal Care, Drug
#   12       & Grocery Stores
#   13    Personal Care, Drug
#   14       & Grocery Stores
#   15       Food, Beverage &
#   16                Tobacco
#   Name: Personal Care, Drug, dtype: object, 1       Drug and grocery
#   2           store chains
#   3                  Foods
#   5       Drug and grocery
#   6           store chains
#   7                  Foods
#   9     Agriculture !shing
#   10          and ranching
#   11         Personal care
#   13         Personal care
#   15               Tobacco
#   Name: Personal care, dtype: object], [1                 PepsiCo Inc
#   3         Procter & Gamble Co
#   5            Raia Drogasil SA
#   7           Reckitt Benckiser
#   8                   Group PLC
#   9               Rite Aid Corp
#   11          Sainsbury (J) PLC
#   13            Sprouts Farmers
#   14                 Market Inc
#   15                 Sysco Corp
#   17              "e Hershey Co
#   19    Tootsie Roll Industries
#   20                        Inc
#   21        Treehouse Foods Inc
#   23            Tyson Foods Inc
#   25               Unilever PLC
#   27               Unilever PLC
#   29       United Natural Foods
#   30                        Inc
#   Name: Nestle India Ltd, dtype: object, 1       PEP
#   3        PG
#   5     RADL3
#   7       RB.
#   9       RAD
#   11     SBRY
#   13      SFM
#   15      SYY
#   17      HSY
#   19       TR
#   21      THS
#   23      TSN
#   25     ULVR
#   27       UL
#   29     UNFI
#   Name: 500790, dtype: object, 1                       Nasdaq
#   3               New York Stock
#   4               Exchange, Inc.
#   5     B3 S.A. - Brasil, Bolsa,
#   6                       Balcão
#   7        London Stock Exchange
#   9               New York Stock
#   10              Exchange, Inc.
#   11       London Stock Exchange
#   13                      Nasdaq
#   15              New York Stock
#   16              Exchange, Inc.
#   17              New York Stock
#   18              Exchange, Inc.
#   19              New York Stock
#   20              Exchange, Inc.
#   21              New York Stock
#   22              Exchange, Inc.
#   23              New York Stock
#   24              Exchange, Inc.
#   25       London Stock Exchange
#   27              New York Stock
#   28              Exchange, Inc.
#   29              New York Stock
#   30              Exchange, Inc.
#   Name: BSE LTD, dtype: object, 1      Large Value
#   3      Large Value
#   5     Large Growth
#   7      Large Blend
#   9      Small Value
#   11       Mid Value
#   13     Small Blend
#   15     Large Value
#   17     Large Blend
#   19     Small Blend
#   21     Small Value
#   23       Mid Value
#   25     Large Value
#   27     Large Value
#   29     Small Value
#   Name: Large Growth, dtype: object, 0                 Tobacco
#   1        Food, Beverage &
#   2                 Tobacco
#   3     Personal Care, Drug
#   4        & Grocery Stores
#   5     Personal Care, Drug
#   6        & Grocery Stores
#   7     Personal Care, Drug
#   8        & Grocery Stores
#   9     Personal Care, Drug
#   10       & Grocery Stores
#   11    Personal Care, Drug
#   12       & Grocery Stores
#   13    Personal Care, Drug
#   14       & Grocery Stores
#   15       Food, Beverage &
#   16                Tobacco
#   17       Food, Beverage &
#   18                Tobacco
#   19       Food, Beverage &
#   20                Tobacco
#   21       Food, Beverage &
#   22                Tobacco
#   23       Food, Beverage &
#   24                Tobacco
#   25    Personal Care, Drug
#   26       & Grocery Stores
#   27    Personal Care, Drug
#   28       & Grocery Stores
#   29       Food, Beverage &
#   30                Tobacco
#   Name: Food, Beverage &, dtype: object, 1       Beverage: Soft
#   2               drinks
#   3        Personal care
#   5     Drug and grocery
#   6         store chains
#   7        Personal care
#   9     Drug and grocery
#   10        store chains
#   11    Drug and grocery
#   12        store chains
#   13    Drug and grocery
#   14        store chains
#   15               Foods
#   17               Foods
#   19               Foods
#   21               Foods
#   23               Foods
#   25       Personal care
#   27       Personal care
#   29               Foods
#   Name: Foods, dtype: object], [0                 PepsiCo Inc
#   2         Procter & Gamble Co
#   4            Raia Drogasil SA
#   6           Reckitt Benckiser
#   7                   Group PLC
#   8               Rite Aid Corp
#   10          Sainsbury (J) PLC
#   12            Sprouts Farmers
#   13                 Market Inc
#   14                 Sysco Corp
#   16              "e Hershey Co
#   18    Tootsie Roll Industries
#   19                        Inc
#   20        Treehouse Foods Inc
#   22            Tyson Foods Inc
#   24               Unilever PLC
#   26               Unilever PLC
#   28       United Natural Foods
#   29                        Inc
#   Name: Unnamed: 0, dtype: object, 0       PEP
#   2        PG
#   4     RADL3
#   6       RB.
#   8       RAD
#   10     SBRY
#   12      SFM
#   14      SYY
#   16      HSY
#   18       TR
#   20      THS
#   22      TSN
#   24     ULVR
#   26       UL
#   28     UNFI
#   Name: Unnamed: 1, dtype: object, 0                       Nasdaq
#   2               New York Stock
#   3               Exchange, Inc.
#   4     B3 S.A. - Brasil, Bolsa,
#   5                       Balcão
#   6        London Stock Exchange
#   8               New York Stock
#   9               Exchange, Inc.
#   10       London Stock Exchange
#   12                      Nasdaq
#   14              New York Stock
#   15              Exchange, Inc.
#   16              New York Stock
#   17              Exchange, Inc.
#   18              New York Stock
#   19              Exchange, Inc.
#   20              New York Stock
#   21              Exchange, Inc.
#   22              New York Stock
#   23              Exchange, Inc.
#   24       London Stock Exchange
#   26              New York Stock
#   27              Exchange, Inc.
#   28              New York Stock
#   29              Exchange, Inc.
#   Name: Unnamed: 2, dtype: object, 0      Large Value
#   2      Large Value
#   4     Large Growth
#   6      Large Blend
#   8      Small Value
#   10       Mid Value
#   12     Small Blend
#   14     Large Value
#   16     Large Blend
#   18     Small Blend
#   20     Small Value
#   22       Mid Value
#   24     Large Value
#   26     Large Value
#   28     Small Value
#   Name: Unnamed: 3, dtype: object, 0        Food, Beverage &
#   1                 Tobacco
#   2     Personal Care, Drug
#   3        & Grocery Stores
#   4     Personal Care, Drug
#   5        & Grocery Stores
#   6     Personal Care, Drug
#   7        & Grocery Stores
#   8     Personal Care, Drug
#   9        & Grocery Stores
#   10    Personal Care, Drug
#   11       & Grocery Stores
#   12    Personal Care, Drug
#   13       & Grocery Stores
#   14       Food, Beverage &
#   15                Tobacco
#   16       Food, Beverage &
#   17                Tobacco
#   18       Food, Beverage &
#   19                Tobacco
#   20       Food, Beverage &
#   21                Tobacco
#   22       Food, Beverage &
#   23                Tobacco
#   24    Personal Care, Drug
#   25       & Grocery Stores
#   26    Personal Care, Drug
#   27       & Grocery Stores
#   28       Food, Beverage &
#   29                Tobacco
#   Name: Tobacco, dtype: object, 0       Beverage: Soft
#   1               drinks
#   2        Personal care
#   4     Drug and grocery
#   5         store chains
#   6        Personal care
#   8     Drug and grocery
#   9         store chains
#   10    Drug and grocery
#   11        store chains
#   12    Drug and grocery
#   13        store chains
#   14               Foods
#   16               Foods
#   18               Foods
#   20               Foods
#   22               Foods
#   24       Personal care
#   26       Personal care
#   28               Foods
#   Name: Unnamed: 4, dtype: object, 0                    BP PLC
#   2               Cameco Corp
#   4          Canadian Natural
#   5             Resources Ltd
#   6              Chevron Corp
#   8         China Petroleum &
#   9             Chemical Corp
#   10        China Petroleum &
#   11            Chemical Corp
#   12                CNOOC Ltd
#   14           Coal India Ltd
#   16    Continental Resources
#   17                      Inc
#   18                 Cosan SA
#   20       Energy Transfer LP
#   22         Exxon Mobil Corp
#   24             Glencore PLC
#   26                Hess Corp
#   28             Lamprell PLC
#   Name: Aemetis Inc, dtype: object, 0         BP
#   2        CCJ
#   4        CNQ
#   6        CVX
#   8      00386
#   10       SNP
#   12       CEO
#   14    533278
#   16       CLR
#   18     CSAN3
#   20        ET
#   22       XOM
#   24      GLEN
#   26       HES
#   28       LAM
#   Name: AMTX, dtype: object, 0               New York Stock
#   1               Exchange, Inc.
#   2               New York Stock
#   3               Exchange, Inc.
#   4       Toronto Stock Exchange
#   6               New York Stock
#   7               Exchange, Inc.
#   8          Hong Kong Exchanges
#   9             And Clearing Ltd
#   10              New York Stock
#   11              Exchange, Inc.
#   12              New York Stock
#   13              Exchange, Inc.
#   14                     BSE LTD
#   16              New York Stock
#   17              Exchange, Inc.
#   18    B3 S.A. - Brasil, Bolsa,
#   19                      Balcão
#   20              New York Stock
#   21              Exchange, Inc.
#   22              New York Stock
#   23              Exchange, Inc.
#   24       London Stock Exchange
#   26              New York Stock
#   27              Exchange, Inc.
#   28       London Stock Exchange
#   Name: Nasdaq, dtype: object, 0     Large Blend
#   2      Mid Growth
#   4     Large Value
#   6     Large Blend
#   8     Large Value
#   10    Large Value
#   12    Large Blend
#   14    Large Value
#   16      Mid Value
#   18    Large Blend
#   20      Mid Value
#   22    Large Value
#   24    Large Blend
#   26      Mid Blend
#   28    Small Value
#   Name: Small Blend, dtype: object, 0          Non-renewable
#   1                 Energy
#   2     Alternative Energy
#   4          Non-renewable
#   5                 Energy
#   6          Non-renewable
#   7                 Energy
#   8          Non-renewable
#   9                 Energy
#   10         Non-renewable
#   11                Energy
#   12         Non-renewable
#   13                Energy
#   14         Non-renewable
#   15                Energy
#   16         Non-renewable
#   17                Energy
#   18    Alternative Energy
#   20         Non-renewable
#   21                Energy
#   22         Non-renewable
#   23                Energy
#   24         Non-renewable
#   25                Energy
#   26         Non-renewable
#   27                Energy
#   28      Energy Equipment
#   29            & Services
#   Name: Alternative Energy, dtype: object, 0        Oil: Integrated
#   2     Alternative energy
#   4             Oil: Crude
#   5              producers
#   6        Oil: Integrated
#   8        Oil: Integrated
#   10       Oil: Integrated
#   12            Oil: Crude
#   13             producers
#   14                  Coal
#   16            Oil: Crude
#   17             producers
#   18    Alternative energy
#   20          Gas pipeline
#   22       Oil: Integrated
#   24                  Coal
#   26       Oil: Integrated
#   28    Oil well equipment
#   29          and services
#   Name: Alternative energy, dtype: object], [0        COMPANY NAME
#   1    Nestle India Ltd
#   Name: Unnamed: 0, dtype: object, 0    TICKER
#   1    500790
#   Name: Unnamed: 1, dtype: object, 0    EXCHANGE
#   1     BSE LTD
#   Name: Unnamed: 2, dtype: object, 0           STYLE
#   1    Large Growth
#   Name: EQUITY, dtype: object, 0          SUB-SECTOR
#   1    Food, Beverage &
#   2             Tobacco
#   Name: RUSSELL, dtype: object, 0       RY
#   1    Foods
#   Name: RUSSELL INDUST, dtype: object, 1    COMPANY NAME
#   2     Aemetis Inc
#   Name: ENERGY, dtype: object, 1    TICKER
#   2      AMTX
#   Name: Unnamed: 3, dtype: object, 1    EXCHANGE
#   2      Nasdaq
#   Name: Unnamed: 4, dtype: object, 0         EQUITY
#   1          STYLE
#   2    Small Blend
#   Name: Unnamed: 5, dtype: object, 0               RUSSELL
#   1            SUB-SECTOR
#   2    Alternative Energy
#   Name: Unnamed: 6, dtype: object, 0               RUSSELL
#   1              INDUSTRY
#   2    Alternative energy
#   Name: Unnamed: 7, dtype: object], [1          PetroChina Co Ltd
#   3     Petroleo Brasileiro SA
#   4                  Petrobras
#   5     Petroleo Brasileiro SA
#   6                  Petrobras
#   7                Phillips 66
#   9        Reliance Industries
#   10                       Ltd
#   11     Royal Dutch Shell PLC
#   13                  SJVN Ltd
#   Name: PetroChina Co Ltd, dtype: object, 1        PTR
#   3      PETR3
#   5      PETR4
#   7        PSX
#   9     500325
#   11      RDSA
#   13    533206
#   Name: 00857, dtype: object, 0             And Clearing Ltd
#   1               New York Stock
#   2               Exchange, Inc.
#   3     B3 S.A. - Brasil, Bolsa,
#   4                       Balcão
#   5     B3 S.A. - Brasil, Bolsa,
#   6                       Balcão
#   7               New York Stock
#   8               Exchange, Inc.
#   9                      BSE LTD
#   11       London Stock Exchange
#   13                     BSE LTD
#   Name: Hong Kong Exchanges, dtype: object, 1     Large Blend
#   3     Large Value
#   5     Large Value
#   7     Large Value
#   9     Large Blend
#   11    Large Blend
#   13      Mid Value
#   Name: Large Blend, dtype: object, 0                 Energy
#   1          Non-renewable
#   2                 Energy
#   3          Non-renewable
#   4                 Energy
#   5          Non-renewable
#   6                 Energy
#   7          Non-renewable
#   8                 Energy
#   9          Non-renewable
#   10                Energy
#   11         Non-renewable
#   12                Energy
#   13    Alternative Energy
#   Name: Non-renewable, dtype: object, 1        Oil: Integrated
#   3        Oil: Integrated
#   5        Oil: Integrated
#   7         Oil: Re!ning &
#   8              marketing
#   9         Oil: Re!ning &
#   10             marketing
#   11       Oil: Integrated
#   13    Alternative energy
#   Name: Oil: Integrated, dtype: object], [1              Allstate Corp
#   3        American Express Co
#   5     Artisan Partners Asset
#   6             Management Inc
#   8                  Aviva PLC
#   10             Axis Bank Ltd
#   11      B3 SA - Brasil Bolsa
#   12                    Balcao
#   14         Bajaj Finserv Ltd
#   16         Banco BTG Pactual
#   17                      S.A.
#   19     Banco do Brasil SA BB
#   20                    Brasil
#   21           Banco Santander
#   22               (Brasil) SA
#   23          Bank Bradesco SA
#   25          Bank Bradesco SA
#   27         Bank Of Ningbo Co
#   28                       Ltd
#   29       Bank of Nova Scotia
#   30                  Bank OZK
#   31              Barclays PLC
#   Name: A$ac Inc, dtype: object, 1        ALL
#   3        AXP
#   5       APAM
#   8        AV.
#   10    532215
#   11     B3SA3
#   14    532978
#   16    BPAC11
#   19     BBAS3
#   21    SANB11
#   23     BBDC3
#   25     BBDC4
#   27    002142
#   29       BNS
#   30       OZK
#   31       BCS
#   Name: AFL, dtype: object, 0               Exchange, Inc.
#   1               New York Stock
#   2               Exchange, Inc.
#   3               New York Stock
#   4               Exchange, Inc.
#   5               New York Stock
#   6               Exchange, Inc.
#   8        London Stock Exchange
#   10                     BSE LTD
#   11    B3 S.A. - Brasil, Bolsa,
#   12                      Balcão
#   14                     BSE LTD
#   16    B3 S.A. - Brasil, Bolsa,
#   17                      Balcão
#   19    B3 S.A. - Brasil, Bolsa,
#   20                      Balcão
#   21    B3 S.A. - Brasil, Bolsa,
#   22                      Balcão
#   23    B3 S.A. - Brasil, Bolsa,
#   24                      Balcão
#   25    B3 S.A. - Brasil, Bolsa,
#   26                      Balcão
#   27     Shenzhen Stock Exchange
#   29      Toronto Stock Exchange
#   30                      Nasdaq
#   31              New York Stock
#   32              Exchange, Inc.
#   Name: New York Stock, dtype: object, 1       Large Value
#   3       Large Blend
#   5       Small Value
#   8         Mid Value
#   10      Large Blend
#   11     Large Growth
#   14     Large Growth
#   16    Not Available
#   19      Large Value
#   21    Not Available
#   23      Large Value
#   25      Large Value
#   27      Large Blend
#   29      Large Value
#   30      Small Blend
#   31      Large Value
#   Name: Large Value, dtype: object, 1             Insurance
#   3      Consumer Finance
#   4     & Credit Services
#   5            Investment
#   6             Banking &
#   7             Brokerage
#   8             Insurance
#   10                Banks
#   11           Investment
#   12            Banking &
#   13            Brokerage
#   14            Insurance
#   16           Investment
#   17            Banking &
#   18            Brokerage
#   19                Banks
#   21                Banks
#   23                Banks
#   25                Banks
#   27                Banks
#   29                Banks
#   30                Banks
#   31                Banks
#   Name: Insurance, dtype: object, 1            Insurance:
#   2     Property-casualty
#   3      Financial data &
#   4               systems
#   5      Asset management
#   6           & custodian
#   8     Insurance: Multi-
#   9                  line
#   10    Banks: Diversi!ed
#   11           Securities
#   12          brokerage &
#   13             services
#   14    Insurance: Multi-
#   15                 line
#   16           Diversi!ed
#   17    !nancial services
#   19    Banks: Diversi!ed
#   21    Banks: Diversi!ed
#   23    Banks: Diversi!ed
#   25    Banks: Diversi!ed
#   27    Banks: Diversi!ed
#   29    Banks: Diversi!ed
#   30    Banks: Diversi!ed
#   31    Banks: Diversi!ed
#   Name: Insurance: Life, dtype: object], [0                       SA
#   1         Canadian Western
#   2                     Bank
#   3       China Construction
#   4                Bank Corp
#   5     China Finance Online
#   6                   Co Ltd
#   7       China Vanke Co Ltd
#   9       China Vanke Co Ltd
#   11       China World Trade
#   12           Center Co Ltd
#   13                Cielo SA
#   15           Citigroup Inc
#   18          City of London
#   19    Investment Group PLC
#   21     Credit Suisse Group
#   22                      AG
#   24        Deutsche Bank AG
#   Name: BR Malls Participacoes, dtype: object, 1        CWB
#   3      00939
#   5       JRJC
#   7      02202
#   9     000002
#   11    600007
#   13     CIEL3
#   15         C
#   18      CLIG
#   21        CS
#   24        DB
#   Name: BRML3, dtype: object, 0                       Balcão
#   1       Toronto Stock Exchange
#   3          Hong Kong Exchanges
#   4             And Clearing Ltd
#   5                       Nasdaq
#   7          Hong Kong Exchanges
#   8             And Clearing Ltd
#   9      Shenzhen Stock Exchange
#   11     Shanghai Stock Exchange
#   13    B3 S.A. - Brasil, Bolsa,
#   14                      Balcão
#   15              New York Stock
#   16              Exchange, Inc.
#   18       London Stock Exchange
#   21              New York Stock
#   22              Exchange, Inc.
#   24              New York Stock
#   Name: B3 S.A. - Brasil, Bolsa,, dtype: object, 1       Small Blend
#   3       Large Value
#   5     Not Available
#   7       Large Blend
#   9       Large Blend
#   11        Mid Blend
#   13        Mid Value
#   15      Large Value
#   18      Small Value
#   21      Large Value
#   24      Large Value
#   Name: Mid Value, dtype: object, 1                 Banks
#   3                 Banks
#   5      Consumer Finance
#   6     & Credit Services
#   7           Real Estate
#   9           Real Estate
#   11          Real Estate
#   13     Consumer Finance
#   14    & Credit Services
#   15           Investment
#   16            Banking &
#   17            Brokerage
#   18           Investment
#   19            Banking &
#   20            Brokerage
#   21           Investment
#   22            Banking &
#   23            Brokerage
#   24           Investment
#   Name: Real Estate, dtype: object, 0         and development
#   1       Banks: Diversi!ed
#   3       Banks: Diversi!ed
#   5        Financial data &
#   6                 systems
#   7     Real estate holding
#   8         and development
#   9     Real estate holding
#   10        and development
#   11        Diversi!ed real
#   12      estate activities
#   13       Financial data &
#   14                systems
#   15             Diversi!ed
#   16      !nancial services
#   18       Asset management
#   19            & custodian
#   21             Diversi!ed
#   22      !nancial services
#   24             Diversi!ed
#   Name: Real estate holding, dtype: object], [0                        Ltd
#   1                MetLife Inc
#   3        Moody’s Corporation
#   5                  Multiplan
#   6            Empreendimentos
#   7            Imobiliarios SA
#   8          NatWest Group PLC
#   9       Old National Bancorp
#   10               Oppenheimer
#   11              Holdings Inc
#   13       PayPal Holdings Inc
#   15         Physicians Realty
#   16                     Trust
#   18         Ping An Insurance
#   19      (Group) Co. of China
#   20                       Ltd
#   21    PNC Financial Services
#   22                 Group Inc
#   23           Porto Seguro SA
#   25      Prudential Financial
#   26                       Inc
#   27            Public Storage
#   Name: Max Financial Services, dtype: object, 1       MET
#   3       MCO
#   5     MULT3
#   8       NWG
#   9       ONB
#   10      OPY
#   13     PYPL
#   15      DOC
#   18    02318
#   21      PNC
#   23    PSSA3
#   25      PRU
#   27      PSA
#   Name: 500271, dtype: object, 1               New York Stock
#   2               Exchange, Inc.
#   3               New York Stock
#   4               Exchange, Inc.
#   5     B3 S.A. - Brasil, Bolsa,
#   6                       Balcão
#   8        London Stock Exchange
#   9                       Nasdaq
#   10              New York Stock
#   11              Exchange, Inc.
#   13                      Nasdaq
#   15              New York Stock
#   16              Exchange, Inc.
#   18         Hong Kong Exchanges
#   19            And Clearing Ltd
#   21              New York Stock
#   22              Exchange, Inc.
#   23    B3 S.A. - Brasil, Bolsa,
#   24                      Balcão
#   25              New York Stock
#   26              Exchange, Inc.
#   27              New York Stock
#   Name: BSE LTD, dtype: object, 1      Large Value
#   3     Large Growth
#   5       Mid Growth
#   8      Large Value
#   9      Small Value
#   10     Small Value
#   13    Large Growth
#   15     Small Blend
#   18     Large Value
#   21     Large Value
#   23       Mid Blend
#   25     Large Value
#   27     Large Value
#   Name: Mid Blend, dtype: object, 1             Insurance
#   3      Consumer Finance
#   4     & Credit Services
#   5           Real Estate
#   8                 Banks
#   9                 Banks
#   10           Investment
#   11            Banking &
#   12            Brokerage
#   13     Consumer Finance
#   14    & Credit Services
#   15          Real Estate
#   16    Investment Trusts
#   17              (REITs)
#   18            Insurance
#   21                Banks
#   23            Insurance
#   25            Insurance
#   27          Real Estate
#   Name: Insurance, dtype: object, 1       Insurance: Multi-
#   2                    line
#   3        Financial data &
#   4                 systems
#   5     Real estate holding
#   6         and development
#   8       Banks: Diversi!ed
#   9       Banks: Diversi!ed
#   10       Asset management
#   11            & custodian
#   13       Financial data &
#   14                systems
#   15           Equity REIT:
#   16            Health Care
#   18        Insurance: Life
#   21      Banks: Diversi!ed
#   23      Insurance: Multi-
#   24                   line
#   25        Insurance: Life
#   27           Equity REIT:
#   Name: Insurance: Life, dtype: object], [1         "e GEO Group Inc
#   4             UBS Group AG
#   7                 Visa Inc
#   9         Wells Fargo & Co
#   11    Westpac Banking Corp
#   13            Yes Bank Ltd
#   Name: Sul America SA, dtype: object, 1        GEO
#   4        UBS
#   7          V
#   9        WFC
#   11       WBK
#   13    532648
#   Name: SULA11, dtype: object, 0             Balcão
#   1     New York Stock
#   2     Exchange, Inc.
#   4     New York Stock
#   5     Exchange, Inc.
#   7     New York Stock
#   8     Exchange, Inc.
#   9     New York Stock
#   10    Exchange, Inc.
#   11    New York Stock
#   12    Exchange, Inc.
#   13           BSE LTD
#   Name: B3 S.A. - Brasil, Bolsa,, dtype: object, 1      Small Value
#   4      Large Value
#   7     Large Growth
#   9      Large Value
#   11     Large Value
#   13     Large Value
#   Name: Not Available, dtype: object, 1           Real Estate
#   2     Investment Trusts
#   3               (REITs)
#   4            Investment
#   5             Banking &
#   6             Brokerage
#   7      Consumer Finance
#   8     & Credit Services
#   9                 Banks
#   11                Banks
#   13                Banks
#   Name: Insurance, dtype: object, 0                   line
#   1     Equity REIT: Other
#   2              Specialty
#   4       Asset management
#   5            & custodian
#   7       Financial data &
#   8                systems
#   9      Banks: Diversi!ed
#   11     Banks: Diversi!ed
#   13     Banks: Diversi!ed
#   Name: Insurance: Multi-, dtype: object], [0                Systems Inc
#   2                   Catalyst
#   3        Pharmaceuticals Inc
#   4               Centene Corp
#   7                  Cipla Ltd
#   9                 Dr Reddy’s
#   10          Laboratories Ltd
#   11        Endo International
#   12                       PLC
#   13       Gilead Sciences Inc
#   15       GlaxoSmithKline PLC
#   17        Globus Medical Inc
#   20        Granules India Ltd
#   22    Harvard Bioscience Inc
#   24                 Hypera SA
#   26              Illumina Inc
#   28           Jiangsu Hengrui
#   29           Medicine Co Ltd
#   30         Johnson & Johnson
#   32                Mediclinic
#   33         International PLC
#   34            Merck & Co Inc
#   36       Myriad Genetics Inc
#   Name: Cardiovascular, dtype: object, 2       CPRX
#   4        CNC
#   7     500087
#   9     500124
#   11      ENDP
#   13      GILD
#   15       GSK
#   17      GMED
#   20    532482
#   22      HBIO
#   24     HYPE3
#   26      ILMN
#   28    600276
#   30       JNJ
#   32       MDC
#   34       MRK
#   36      MYGN
#   Name: CSII, dtype: object, 2                       Nasdaq
#   4               New York Stock
#   5               Exchange, Inc.
#   7                      BSE LTD
#   9                      BSE LTD
#   11                      Nasdaq
#   13                      Nasdaq
#   15              New York Stock
#   16              Exchange, Inc.
#   17              New York Stock
#   18              Exchange, Inc.
#   20                     BSE LTD
#   22                      Nasdaq
#   24    B3 S.A. - Brasil, Bolsa,
#   25                      Balcão
#   26                      Nasdaq
#   28     Shanghai Stock Exchange
#   30              New York Stock
#   31              Exchange, Inc.
#   32       London Stock Exchange
#   34              New York Stock
#   35              Exchange, Inc.
#   36                      Nasdaq
#   Name: Nasdaq, dtype: object, 2     Small Growth
#   4      Large Blend
#   7      Large Blend
#   9      Large Blend
#   11     Small Value
#   13     Large Value
#   15     Large Value
#   17      Mid Growth
#   20      Mid Growth
#   22     Small Value
#   24     Large Blend
#   26    Large Growth
#   28    Large Growth
#   30     Large Value
#   32     Small Value
#   34     Large Value
#   36     Small Value
#   Name: Small Growth, dtype: object, 0          And Services
#   2     Pharmaceuticals &
#   3               Biotech
#   4           Health Care
#   5              Services
#   7     Pharmaceuticals &
#   8               Biotech
#   9     Pharmaceuticals &
#   10              Biotech
#   11    Pharmaceuticals &
#   12              Biotech
#   13    Pharmaceuticals &
#   14              Biotech
#   15    Pharmaceuticals &
#   16              Biotech
#   17    Medical Equipment
#   18         And Services
#   20    Pharmaceuticals &
#   21              Biotech
#   22    Pharmaceuticals &
#   23              Biotech
#   24    Pharmaceuticals &
#   25              Biotech
#   26    Medical Equipment
#   27         And Services
#   28    Pharmaceuticals &
#   29              Biotech
#   30    Pharmaceuticals &
#   31              Biotech
#   32          Health Care
#   33             Services
#   34    Pharmaceuticals &
#   35              Biotech
#   36    Pharmaceuticals &
#   37              Biotech
#   Name: Medical Equipment, dtype: object, 0         instruments &
#   1              supplies
#   2         Biotechnology
#   4           Health care
#   5            management
#   6              services
#   7       Pharmaceuticals
#   9       Pharmaceuticals
#   11      Pharmaceuticals
#   13      Pharmaceuticals
#   15      Pharmaceuticals
#   17     Medical & dental
#   18        instruments &
#   19             supplies
#   20      Pharmaceuticals
#   22        Biotechnology
#   24      Pharmaceuticals
#   26    Medical equipment
#   28      Pharmaceuticals
#   30      Pharmaceuticals
#   32          Health care
#   33           facilities
#   34      Pharmaceuticals
#   36        Biotechnology
#   Name: Medical & dental, dtype: object], [Series([], Name: Regeneron, dtype: int64),
#   Series([], Name: REGN, dtype: int64),
#   Series([], Name: Nasdaq, dtype: int64),
#   Series([], Name: Large Growth, dtype: int64),
#   Series([], Name: Pharmaceuticals &, dtype: int64),
#   Series([], Name: Biotechnology, dtype: int64)], [Series([], Name: Anhui Conch Cement, dtype: int64),
#   Series([], Name: 600585, dtype: int64),
#   Series([], Name: Shanghai Stock Exchange, dtype: int64),
#   Series([], Name: Large Blend, dtype: int64),
#   Series([], Name: Building Materials, dtype: int64),
#   Series([], Name: Cement, dtype: int64)], [0                      Inc
#   1              Fuwei Films
# ...
#   6          Smiths Group PLC
#   9               Snap-on Inc
#   11    Southwest Airlines Co
#   13      Spirit Airlines Inc
#   15         "e Middleby Corp
#   17      Titan International
#   18                      Inc
#   19     Verisk Analytics Inc
#   21     Wabash National Corp
#   Name: Rumo SA, dtype: object, 1     600009
#   4       SKYW
#   6       SMIN
#   9        SNA
#   11       LUV
#   13      SAVE
#   15      MIDD
#   17       TWI
#   19      VRSK
#   21       WNC
#   Name: RAIL3, dtype: object, 0                      Balcão
#   1     Shanghai Stock Exchange
#   4                      Nasdaq
#   6       London Stock Exchange
#   9              New York Stock
#   10             Exchange, Inc.
#   11             New York Stock
#   12             Exchange, Inc.
#   13             New York Stock
#   14             Exchange, Inc.
#   15                     Nasdaq
#   17             New York Stock
#   18             Exchange, Inc.
#   19                     Nasdaq
#   21             New York Stock
#   22             Exchange, Inc.
#   Name: B3 S.A. - Brasil, Bolsa,, dtype: object, 1     Large Growth
#   4      Small Value
#   6        Mid Value
#   9        Mid Value
#   11       Mid Value
#   13     Small Blend
#   15       Mid Blend
#   17     Small Value
#   19     Large Blend
#   21     Small Value
#   Name: Large Growth, dtype: object, 0              Freight
#   1     Transportation &
#   2              Freight
#   4     Transportation &
#   5              Freight
#   6      Manufacturing &
#   7           Production
#   9            Machinery
#   11    Transportation &
#   12             Freight
#   13    Transportation &
#   14             Freight
#   15           Machinery
#   17           Machinery
#   19          Commercial
#   20            Services
#   21    Transportation &
#   22             Freight
#   Name: Transportation &, dtype: object, 0          miscellaneous
#   1          Air transport
#   4          Air transport
#   6             Diversi!ed
#   7          manufacturing
#   8             operations
#   9       Machinery: Tools
#   11         Air transport
#   13         Air transport
#   15            Machinery:
#   16            Industrial
#   17            Machinery:
#   18          Agricultural
#   19    Back o%ce support,
#   20       HR & consulting
#   21            Commercial
#   22    vehicles and parts
#   Name: Transportation, dtype: object], [1    Alibaba Group Holding
#   2                      Ltd
#   3             Alphabet Inc
#   Name: Adobe Inc, dtype: object, 1    BABA
#   3    GOOG
#   Name: ADBE, dtype: object, 1    New York Stock
#   2    Exchange, Inc.
#   3            Nasdaq
#   Name: Nasdaq, dtype: object, 1    Large Growth
#   3    Large Growth
#   Name: Large Growth, dtype: object, 0     Technology
#   1    Information
#   2     Technology
#   3    Information
#   4     Technology
#   Name: Information, dtype: object, 0    software and systems
#   1       Computer services
#   2    software and systems
#   3       Computer services
#   4    software and systems
#   Name: Computer services, dtype: object], [1            Astra Microwave
#   2               Products Ltd
#   3                  Baidu Inc
#   5            Bene!tfocus Inc
#   7       Cognizant Technology
#   8             Solutions Corp
#   9     Constellation Software
#   10                       Inc
#   11      discoverIE Group PLC
#   12         DXC Technology Co
#   14      Enghouse Systems Ltd
#   16              Facebook Inc
#   18        Foxconn Industrial
#   19           Internet Co Ltd
#   20               Groupon Inc
#   22       Hangzhou Hik-Vision
#   23     Digital Technology Co
#   24                       Ltd
#   25      HCL Technologies Ltd
#   27                  Hexaware
#   28          Technologies Ltd
#   29               Infosys Ltd
#   31             Just Dial Ltd
#   33      Manhattan Associates
#   34                       Inc
#   35          Meituan Dianping
#   37               Micro Focus
#   38         International PLC
#   39            Microsoft Corp
#   41              MindTree Ltd
#   Name: Arista Networks Inc, dtype: object, 1     532493
#   3       BIDU
#   5       BNFT
#   7       CTSH
#   9        CSU
#   11      DSCV
#   12       DXC
#   14      ENGH
#   16        FB
#   18    601138
#   20      GRPN
#   22    002415
#   25    532281
#   27    532129
#   29    500209
#   31    535648
#   33      MANH
#   35     03690
#   37      MCRO
#   39      MSFT
#   41    532819
#   Name: ANET, dtype: object, 0            Exchange, Inc.
#   1                   BSE LTD
#   3                    Nasdaq
#   5                    Nasdaq
#   7                    Nasdaq
#   9             Toronto Stock
#   10                 Exchange
#   11    London Stock Exchange
#   12           New York Stock
#   13           Exchange, Inc.
#   14            Toronto Stock
#   15                 Exchange
#   16                   Nasdaq
#   18           Shanghai Stock
#   19                 Exchange
#   20                   Nasdaq
#   22           Shenzhen Stock
#   23                 Exchange
#   25                  BSE LTD
#   27                  BSE LTD
#   29                  BSE LTD
#   31                  BSE LTD
#   33                   Nasdaq
#   35      Hong Kong Exchanges
#   36         And Clearing Ltd
#   37    London Stock Exchange
#   39                   Nasdaq
#   41                  BSE LTD
#   Name: New York Stock, dtype: object, 1       Small Blend
#   3     Not Available
#   5      Small Growth
#   7       Large Blend
#   9      Large Growth
#   11     Small Growth
#   12        Mid Value
#   14       Mid Growth
#   16     Large Growth
#   18      Large Value
#   20      Small Value
#   22      Large Blend
#   25      Large Blend
#   27       Mid Growth
#   29      Large Blend
#   31     Small Growth
#   33        Mid Blend
#   35    Not Available
#   37      Small Value
#   39     Large Growth
#   41        Mid Blend
#   Name: Mid Growth, dtype: object, 0            Technology
#   1     Telecommunication
#   3           Information
#   4            Technology
#   5           Information
#   6            Technology
#   7           Information
#   8            Technology
#   9           Information
#   10           Technology
#   11          Electronics
#   12          Information
#   13           Technology
#   14          Information
#   15           Technology
#   16          Information
#   17           Technology
#   18    Telecommunication
#   20          Information
#   21           Technology
#   22          Electronics
#   25          Information
#   26           Technology
#   27          Information
#   28           Technology
#   29          Information
#   30           Technology
#   31          Information
#   32           Technology
#   33          Information
#   34           Technology
#   35          Information
#   36           Technology
#   37          Information
#   38           Technology
#   39          Information
#   40           Technology
#   41          Information
#   42           Technology
#   Name: Information, dtype: object, 0     software and systems
#   1       Telecommunications
#   2                equipment
#   3        Computer services
#   4     software and systems
#   5        Computer services
#   6     software and systems
#   7        Computer services
#   8     software and systems
#   9        Computer services
#   10    software and systems
#   11             Electronics
#   12       Computer services
#   13    software and systems
#   14       Computer services
#   15    software and systems
#   16       Computer services
#   17    software and systems
#   18      Telecommunications
#   19               equipment
#   20       Computer services
#   21    software and systems
#   22              Electronic
#   23              components
#   25       Computer services
#   26    software and systems
#   27       Computer services
#   28    software and systems
#   29       Computer services
#   30    software and systems
#   31       Computer services
#   32    software and systems
#   33       Computer services
#   34    software and systems
#   35       Computer services
#   36    software and systems
#   37       Computer services
#   38    software and systems
#   39       Computer services
#   40    software and systems
#   41       Computer services
#   42    software and systems
#   Name: Computer services, dtype: object], [0               Power Co Inc
#   1             American Water
#   2               Works Co Inc
#   3                   AT&T Inc
#   5                    BCE Inc
#   7          Bharti Airtel Ltd
#   9               BT Group PLC
#   11    Canadian Utilities Ltd
#   13        Centrais Eletricas
#   14            Brasileiras SA
#   15        Centrais Eletricas
#   16            Brasileiras SA
#   17        China Gas Holdings
#   18                       Ltd
#   19          China Mobile Ltd
#   21          China Mobile Ltd
#   23        China Telecom Corp
#   24                       Ltd
#   25        China Unicom (Hong
#   26                 Kong) Ltd
#   Name: American Electric, dtype: object, 1        AWK
#   3          T
#   5        BCE
#   7     532454
#   9       BT.A
#   11        CU
#   13     ELET3
#   15     ELET6
#   17     00384
#   19     00941
#   21       CHL
#   23       CHA
#   25       CHU
#   Name: AEP, dtype: object, 0               Exchange, Inc.
#   1               New York Stock
#   2               Exchange, Inc.
#   3               New York Stock
#   4               Exchange, Inc.
#   5       Toronto Stock Exchange
#   7                      BSE LTD
#   9        London Stock Exchange
#   11      Toronto Stock Exchange
#   13    B3 S.A. - Brasil, Bolsa,
#   14                      Balcão
#   15    B3 S.A. - Brasil, Bolsa,
#   16                      Balcão
#   17         Hong Kong Exchanges
#   18            And Clearing Ltd
#   19         Hong Kong Exchanges
#   20            And Clearing Ltd
#   21              New York Stock
#   22              Exchange, Inc.
#   23              New York Stock
#   24              Exchange, Inc.
#   25              New York Stock
#   26              Exchange, Inc.
#   Name: New York Stock, dtype: object, 1       Mid Blend
#   3     Large Value
#   5     Large Blend
#   7     Large Value
#   9       Mid Value
#   11      Mid Blend
#   13    Large Value
#   15    Large Value
#   17    Large Blend
#   19    Large Value
#   21    Large Value
#   23    Large Value
#   25    Large Value
#   Name: Large Value, dtype: object, 1     Utilities
#   3     Utilities
#   5     Utilities
#   7     Utilities
#   9     Utilities
#   11    Utilities
#   13    Utilities
#   15    Utilities
#   17    Utilities
#   19    Utilities
#   21    Utilities
#   23    Utilities
#   25    Utilities
#   Name: Utilities, dtype: object, 1          Utilities: Water
#   3                Utilities:
#   4        Telecommunications
#   5                Utilities:
#   6        Telecommunications
#   7                Utilities:
#   8        Telecommunications
#   9                Utilities:
#   10       Telecommunications
#   11               Utilities:
#   12            Miscellaneous
#   13    Utilities: Electrical
#   15    Utilities: Electrical
#   17           Utilities: Gas
#   18             distributors
#   19               Utilities:
#   20       Telecommunications
#   21               Utilities:
#   22       Telecommunications
#   23               Utilities:
#   24       Telecommunications
#   25               Utilities:
#   26       Telecommunications
#   Name: Utilities: Electrical, dtype: object], [0                        SA
#   1     Equatorial Energia SA
#   3          FirstEnergy Corp
#   5          GAIL (India) Ltd
#   7                  Gogo Inc
#   9        GTT Communications
#   10                      Inc
#   11       Gujarat Industries
#   12             Power Co Ltd
#   13            Huaneng Power
#   14        International Inc
#   15      Mahanagar Telephone
#   16                Nigam Ltd
#   17       Middlesex Water Co
#   18     National Fuel Gas Co
#   20                 NTPC Ltd
#   21                PG&E Corp
#   23       Power Grid Corp Of
#   24                India Ltd
#   25            Sempra Energy
#   27         Severn Trent PLC
#   28                SJW Group
#   30              Southern Co
#   32                  SSE PLC
#   33        Tata Power Co Ltd
#   34     Telefonica Brasil SA
#   36         "e York Water Co
#   Name: ENGIE Brasil Energia, dtype: object, 1      EQTL3
#   3         FE
#   5     532155
#   7       GOGO
#   9        GTT
#   11    517300
#   13       HNP
#   15    500108
#   17      MSEX
#   18       NFG
#   20    532555
#   21       PCG
#   23    532898
#   25       SRE
#   27       SVT
#   28       SJW
#   30        SO
#   32       SSE
#   33    500400
#   34     VIVT4
#   36      YORW
#   Name: EGIE3, dtype: object, 0                       Balcão
#   1     B3 S.A. - Brasil, Bolsa,
#   2                       Balcão
#   3               New York Stock
#   4               Exchange, Inc.
#   5                      BSE LTD
#   7                       Nasdaq
#   9               New York Stock
#   10              Exchange, Inc.
#   11                     BSE LTD
#   13              New York Stock
#   14              Exchange, Inc.
#   15                     BSE LTD
#   17                      Nasdaq
#   18              New York Stock
#   19              Exchange, Inc.
#   20                     BSE LTD
#   21              New York Stock
#   22              Exchange, Inc.
#   23                     BSE LTD
#   25              New York Stock
#   26              Exchange, Inc.
#   27       London Stock Exchange
#   28              New York Stock
#   29              Exchange, Inc.
#   30              New York Stock
#   31              Exchange, Inc.
#   32       London Stock Exchange
#   33                     BSE LTD
#   34    B3 S.A. - Brasil, Bolsa,
#   35                      Balcão
#   36                      Nasdaq
#   Name: B3 S.A. - Brasil, Bolsa,, dtype: object, 1     Large Growth
#   3        Mid Value
#   5      Large Value
#   7      Small Blend
#   9      Small Blend
#   11     Small Value
#   13     Large Value
#   15     Small Value
#   17     Small Blend
#   18     Small Value
#   20     Large Value
#   21       Mid Value
#   23     Large Value
#   25     Large Value
#   27       Mid Value
#   28     Small Blend
#   30     Large Value
#   32     Large Value
#   33       Mid Value
#   34     Large Value
#   36     Small Blend
#   Name: Large Blend, dtype: object, 1     Utilities
#   3     Utilities
#   5     Utilities
#   7     Utilities
#   9     Utilities
#   11    Utilities
#   13    Utilities
#   15    Utilities
#   17    Utilities
#   18    Utilities
#   20    Utilities
#   21    Utilities
#   23    Utilities
#   25    Utilities
#   27    Utilities
#   28    Utilities
#   30    Utilities
#   32    Utilities
#   33    Utilities
#   34    Utilities
#   36    Utilities
#   Name: Utilities, dtype: object, 1     Utilities: Electrical
#   3     Utilities: Electrical
#   5            Utilities: Gas
#   6              distributors
#   7                Utilities:
#   8        Telecommunications
#   9                Utilities:
#   10       Telecommunications
#   11    Utilities: Electrical
#   13    Utilities: Electrical
#   15               Utilities:
#   16       Telecommunications
#   17         Utilities: Water
#   18           Utilities: Gas
#   19             distributors
#   20    Utilities: Electrical
#   21    Utilities: Electrical
#   23    Utilities: Electrical
#   25               Utilities:
#   26            Miscellaneous
#   27         Utilities: Water
#   28         Utilities: Water
#   30    Utilities: Electrical
#   32    Utilities: Electrical
#   33    Utilities: Electrical
#   34               Utilities:
#   35       Telecommunications
#   36         Utilities: Water
#   Name: Utilities: Electrical, dtype: object], [0              COMPANY NAME
#   1    United Utilities Group
#   2                       PLC
#   3                   Verizon
#   4        Communications Inc
#   5        Vodafone Group PLC
#   7        Vodafone Group PLC
#   Name: Unnamed: 0, dtype: object, 0    TICKER
#   1       UU.
#   3        VZ
#   5       VOD
#   7       VOD
#   Name: Unnamed: 1, dtype: object, 0                 EXCHANGE
#   1    London Stock Exchange
#   3           New York Stock
#   4           Exchange, Inc.
#   5    London Stock Exchange
#   7                   Nasdaq
#   Name: Unnamed: 2, dtype: object, 0          STYLE
#   1      Mid Value
#   3    Large Value
#   5    Large Value
#   7    Large Value
#   Name: EQUITY, dtype: object, 0    SUB-SECTOR
#   1     Utilities
#   3     Utilities
#   5     Utilities
#   7     Utilities
#   Name: RUSSELL, dtype: object, 0      RUSSELL INDUSTRY
#   1      Utilities: Water
#   3            Utilities:
#   4    Telecommunications
#   5            Utilities:
#   6    Telecommunications
#   7            Utilities:
#   Name: Unnamed: 3, dtype: object]]

# %% [markdown]
# 3. Run pd.concat on each list of series and then again on the output
# 4. Once we run pd.concat for the second time, we will have a dataframe with only one column
#
# ##### The cell below turns our list of list of pandas series objects into one pandas object with one column

# %%
data = list(map(lambda x: pd.concat(series_list[x], ignore_index=True), range(len(series_list))))
data = pd.concat(data)
data
# Out:
# 0                      Co
# 1     Acorn International
# 2                     Inc
# 3          Amazon.com Inc
# 4          American Eagle
#              ...
# 30             Utilities:
# 31     Telecommunications
# 32             Utilities:
# 33     Telecommunications
# 34             Utilities:
# Length: 2534, dtype: object

# %% [markdown]
# ###### Two filters
# 3. Filter the series by length<7 because the tickers all have less than seven characters (Some of the tickers are quite long)
# 4. Filter by words we don't want that are less than seven characters in length.
#
# ##### The cell below filters data by character length and words less than 7 characters that we don't want in our list

# %%
bad_words = ["Retail", "Media", "Foods", "Nasdaq", "EQUITY", "Cement", "Copper", "ENERGY", "Inc", "Co", "STYLE", "TICKER", "Balcão"]
filtered_data = data[(data.str.len()<7) & (data.isin(bad_words)==False)]
filtered_data
# Out:
# 32     ATV
# 33    AMZN
# 34     AEO
# 35    APTV
# 36     AVP
#       ...
# 2      PLC
# 8      UU.
# 9       VZ
# 10     VOD
# 11     VOD
# Length: 406, dtype: object

# %% [markdown]
# ##### Tabula took some of the tickers from the PDF file and assigned them to column names.
# We want to make sure we don't leave any of the tickers out. So, we also need to:
# 5. Filter the column list by bad words and length less than 7
# 6. Append to the filtered_data pandas series object.
#
# ##### The cell below uses itertools to unzip the list of lists of column names into one list and then filters it.

# %%
'''
Unzips the column list and puts all the column names into one list (versus having a list of lists)
'''

columns_one_list = list(itertools.chain.from_iterable(columns_list)) #itertools will turn the list of list into one list
columns_list_filtered = [x for x in columns_one_list if (len(x) < 7) & (x not in bad_words)] #Filter by less than 7 and bad words

# %%
#append the columns to the filtered_data_series
final_lists = append_columns(columns_list_filtered, filtered_data)

# %%
final_lists
# Out:
# 0        ATV
# 1       AMZN
# 2        AEO
# 3       APTV
# 4        AVP
#        ...
# 423    RAIL3
# 424     ADBE
# 425     ANET
# 426      AEP
# 427    EGIE3
# Length: 428, dtype: object

# %% [markdown]
# ##### There are duplicates in our pandas series
# 7. Remove duplicate values

# %%
final_lists[final_lists=='VOD']
# Out:
# 404    VOD
# 405    VOD
# dtype: object

# %%
#We need to drop duplicates
final_lists = final_lists.drop_duplicates()

# %%
final_lists
# Out:
# 0        ATV
# 1       AMZN
# 2        AEO
# 3       APTV
# 4        AVP
#        ...
# 423    RAIL3
# 424     ADBE
# 425     ANET
# 426      AEP
# 427    EGIE3
# Length: 346, dtype: object

# %%
final_lists.to_excel('stocklist.xlsx')
